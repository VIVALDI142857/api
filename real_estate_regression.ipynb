# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy as sc
from ydata_profiling import ProfileReport
from scipy import stats as sts
import sklearn 
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression, ElasticNet
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, f1_score, mean_absolute_error, r2_score, mean_absolute_percentage_error, mean_squared_log_error, explained_variance_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer, KNNImputer
sklearn.impute.KNNImputer
from sklearn.base import BaseEstimator, TransformerMixin
import phik
from typing import Literal
from lightgbm import LGBMRegressor
import umap
import optuna
from sklearn.pipeline import Pipeline
import mlflow
import mlflow.sklearn  # Если нужно логировать модели sklearn
import os
from mlflow.models import infer_signature
pd.set_option('display.max_columns', None)
from catboost import CatBoostRegressor
from category_encoders import CatBoostEncoder
# %matplotlib
# Out:
#         <div>
#             <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#             <p>
#                 Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#             </p>
#         </div>
# 2025-03-12 17:32:10.885162: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-12 17:32:10.892269: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-12 17:32:10.950893: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-12 17:32:11.010209: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-12 17:32:11.072045: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-12 17:32:11.090978: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-12 17:32:11.206023: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-12 17:32:11.936150: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 28
#      26 import optuna
#      27 from sklearn.pipeline import Pipeline
# ---> 28 import mlflow
#      29 import mlflow.sklearn  # Если нужно логировать модели sklearn
#      30 import os
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/__init__.py:35
#      32 from mlflow.version import VERSION
#      34 __version__ = VERSION
# ---> 35 from mlflow import (
#      36     artifacts,  # noqa: F401
#      37     client,  # noqa: F401
#      38     config,  # noqa: F401
#      39     data,  # noqa: F401
#      40     exceptions,  # noqa: F401
#      41     models,  # noqa: F401
#      42     projects,  # noqa: F401
#      43     tracing,  # noqa: F401
#      44     tracking,  # noqa: F401
#      45 )
#      46 from mlflow.environment_variables import MLFLOW_CONFIGURE_LOGGING
#      47 from mlflow.utils.lazy_load import LazyLoader
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/projects/__init__.py:11
#       7 import os
#       9 import yaml
# ---> 11 import mlflow.projects.databricks
#      12 import mlflow.utils.uri
#      13 from mlflow import tracking
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/projects/databricks.py:19
#      17 from mlflow.exceptions import ExecutionException, MlflowException
#      18 from mlflow.projects.submitted_run import SubmittedRun
# ---> 19 from mlflow.projects.utils import MLFLOW_LOCAL_BACKEND_RUN_ID_CONFIG
#      20 from mlflow.protos.databricks_pb2 import INVALID_PARAMETER_VALUE
#      21 from mlflow.utils import databricks_utils, file_utils, rest_utils
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/projects/utils.py:16
#      14 from mlflow.exceptions import ExecutionException
#      15 from mlflow.projects import _project_spec
# ---> 16 from mlflow.tracking import fluent
#      17 from mlflow.tracking.context.default_context import _get_user
#      18 from mlflow.utils.git_utils import get_git_commit, get_git_repo_url
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/tracking/fluent.py:47
#      45 from mlflow.tracking.client import MlflowClient
#      46 from mlflow.tracking.context import registry as context_registry
# ---> 47 from mlflow.tracking.default_experiment import registry as default_experiment_registry
#      48 from mlflow.utils import get_results_from_paginated_fn
#      49 from mlflow.utils.annotations import experimental
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/tracking/default_experiment/registry.py:53
#      50 for exp_provider in _EXPERIMENT_PROVIDERS:
#      51     _default_experiment_provider_registry.register(exp_provider)
# ---> 53 _default_experiment_provider_registry.register_entrypoints()
#      56 def get_experiment_id():
#      57     """Get an experiment ID for the current context.
#      58
#      59     The experiment ID is fetched by querying providers, in the order that they were registered.
#    (...)
#      63         An experiment_id.
#      64     """
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/tracking/default_experiment/registry.py:35, in DefaultExperimentProviderRegistry.register_entrypoints(self)
#      33 def register_entrypoints(self):
#      34     """Register tracking stores provided by other packages"""
# ---> 35     for entrypoint in get_entry_points("mlflow.default_experiment_provider"):
#      36         try:
#      37             self.register(entrypoint.load())
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/utils/plugins.py:17, in get_entry_points(group)
#      16 def get_entry_points(group: str) -> list[importlib.metadata.EntryPoint]:
# ---> 17     return _get_entry_points(group)
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/utils/plugins.py:7, in _get_entry_points(group)
#       5 def _get_entry_points(group: str) -> list[importlib.metadata.EntryPoint]:
#       6     if sys.version_info >= (3, 10):
# ----> 7         return importlib.metadata.entry_points(group=group)
#       9     entrypoints = importlib.metadata.entry_points()
#      10     try:
#
# File ~/miniconda3/envs/api/lib/python3.10/importlib/metadata/__init__.py:1021, in entry_points(**params)
#    1017 unique = functools.partial(unique_everseen, key=norm_name)
#    1018 eps = itertools.chain.from_iterable(
#    1019     dist.entry_points for dist in unique(distributions())
#    1020 )
# -> 1021 return SelectableGroups.load(eps).select(**params)
#
# File ~/miniconda3/envs/api/lib/python3.10/importlib/metadata/__init__.py:459, in SelectableGroups.load(cls, eps)
#     456 @classmethod
#     457 def load(cls, eps):
#     458     by_group = operator.attrgetter('group')
# --> 459     ordered = sorted(eps, key=by_group)
#     460     grouped = itertools.groupby(ordered, by_group)
#     461     return cls((group, EntryPoints(eps)) for group, eps in grouped)
#
# File ~/miniconda3/envs/api/lib/python3.10/importlib/metadata/__init__.py:1018, in <genexpr>(.0)
#    1016 norm_name = operator.attrgetter('_normalized_name')
#    1017 unique = functools.partial(unique_everseen, key=norm_name)
# -> 1018 eps = itertools.chain.from_iterable(
#    1019     dist.entry_points for dist in unique(distributions())
#    1020 )
#    1021 return SelectableGroups.load(eps).select(**params)
#
# File ~/miniconda3/envs/api/lib/python3.10/importlib/metadata/_itertools.py:16, in unique_everseen(iterable, key)
#      14 else:
#      15     for element in iterable:
# ---> 16         k = key(element)
#      17         if k not in seen:
#      18             seen_add(k)
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/importlib_metadata/__init__.py:972, in PathDistribution._normalized_name(self)
#     966 """
#     967 Performance optimization: where possible, resolve the
#     968 normalized name from the file system path.
#     969 """
#     970 stem = os.path.basename(str(self._path))
#     971 return (
# --> 972     pass_none(Prepared.normalize)(self._name_from_stem(stem))
#     973     or super()._normalized_name
#     974 )
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/importlib_metadata/_functools.py:102, in pass_none.<locals>.wrapper(param, *args, **kwargs)
#      99 @functools.wraps(func)
#     100 def wrapper(param, *args, **kwargs):
#     101     if param is not None:
# --> 102         return func(param, *args, **kwargs)
#
# File ~/miniconda3/envs/api/lib/python3.10/site-packages/importlib_metadata/__init__.py:889, in Prepared.normalize(name)
#     884 @staticmethod
#     885 def normalize(name):
#     886     """
#     887     PEP 503 normalization plus dashes as underscores.
#     888     """
# --> 889     return re.sub(r"[-_.]+", "-", name).lower().replace('-', '_')
#
# File ~/miniconda3/envs/api/lib/python3.10/re.py:209, in sub(pattern, repl, string, count, flags)
#     202 def sub(pattern, repl, string, count=0, flags=0):
#     203     """Return the string obtained by replacing the leftmost
#     204     non-overlapping occurrences of the pattern in string by the
#     205     replacement repl.  repl can be either a string or a callable;
#     206     if a string, backslash escapes in it are processed.  If it is
#     207     a callable, it's passed the Match object and must return
#     208     a replacement string to be used."""
# --> 209     return _compile(pattern, flags).sub(repl, string, count)
#
# KeyboardInterrupt:

# %%
mlflow.set_tracking_uri(mlflow.set_tracking_uri("http://192.168.1.104:5000"))

# %%
mlflow.set_experiment("price_prediction_experiment")
# Out:
# <Experiment: artifact_location='file:///home/vivaldi/MyProjects/ssh_first_try/mlruns/485654732909900912', creation_time=1741637804696, experiment_id='485654732909900912', last_update_time=1741637804696, lifecycle_stage='active', name='price_prediction_experiment', tags={}>

# %%
df = pd.read_csv('data/portugal_listinigs.csv')
# Out:
# /tmp/ipykernel_5739/499035845.py:1: DtypeWarning: Columns (6,8,12,13,14,15,16,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/portugal_listinigs.csv')

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [135536 rows x 25 columns]

# %%
df = df.dropna(subset=['Price'])

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df.drop(index=df[df['Price'] == max(df['Price'])].index, inplace=True)
# Out:
# /tmp/ipykernel_5739/126092300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=df[df['Price'] == max(df['Price'])].index, inplace=True)

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df[df['Price'] > 10000000].sort_values(by='Price', ascending=False)
# Out:
#              Price  District                 City  \
# 82054   36000000.0      Faro            Albufeira
# 64294   36000000.0      Faro            Albufeira
# 120664  25000000.0    Lisboa               Lisboa
# 82055   22000000.0      Faro            Albufeira
# 64229   22000000.0      Faro            Albufeira
# 1749    20000000.0      Faro                Lagos
# 109573  20000000.0   Setúbal              Palmela
# 84705   20000000.0      Faro                Lagos
# 58159   20000000.0   Setúbal              Palmela
# 2560    19500000.0      Faro                Lagos
# 84864   19500000.0      Faro                Lagos
# 56      18500000.0      Faro                 Faro
# 83681   18500000.0      Faro                 Faro
# 131114  18000000.0    Lisboa              Cascais
# 51583   16800000.0      Faro      Lagoa (Algarve)
# 82496   16800000.0      Faro      Lagoa (Algarve)
# 119623  15000000.0    Lisboa              Amadora
# 58986   15000000.0    Lisboa              Cascais
# 93403   15000000.0    Lisboa              Cascais
# 99633   15000000.0     Porto        Vila do Conde
# 1838    15000000.0      Faro               Silves
# 60671   15000000.0     Porto        Vila do Conde
# 84771   15000000.0      Faro               Silves
# 54315   15000000.0    Lisboa              Cascais
# 24906   14300000.0  Santarém                Tomar
# 106891  14300000.0  Santarém                Tomar
# 47733   14300000.0  Santarém                Tomar
# 117785  13000000.0    Lisboa                Mafra
# 127074  12500000.0    Lisboa               Lisboa
# 122249  12500000.0    Lisboa               Lisboa
# 88473   12500000.0    Lisboa               Oeiras
# 1855    12500000.0      Faro            Albufeira
# 1356    12500000.0      Faro                Loulé
# 97349   12500000.0    Lisboa               Sintra
# 95994   12500000.0    Lisboa               Sintra
# 45250   12500000.0    Lisboa               Sintra
# 134251  12500000.0    Lisboa               Sintra
# 84770   12500000.0      Faro            Albufeira
# 6556    12500000.0    Lisboa               Lisboa
# 37636   12500000.0    Lisboa               Sintra
# 83291   12500000.0      Faro                Loulé
# 117383  12000000.0    Lisboa  Vila Franca de Xira
# 29610   12000000.0   Setúbal               Seixal
# 38763   12000000.0    Lisboa              Cascais
# 30349   12000000.0   Setúbal              Setúbal
# 118427  12000000.0   Setúbal              Setúbal
# 87018   12000000.0    Leiria  Figueiró dos Vinhos
# 112231  12000000.0   Setúbal               Seixal
# 9478    12000000.0    Leiria  Figueiró dos Vinhos
# 3866    11850000.0   Coimbra               Penela
# 80119   11850000.0   Coimbra               Penela
# 116842  11000000.0      Faro         Castro Marim
# 110660  11000000.0   Setúbal              Palmela
# 789     11000000.0      Faro         Castro Marim
# 32841   11000000.0   Setúbal              Palmela
# 129301  11000000.0      Faro         Castro Marim
# 84752   11000000.0      Faro         Castro Marim
# 47036   11000000.0    Lisboa               Sintra
# 119909  10995000.0    Lisboa              Cascais
#
#                                                      Town  \
# 82054                           Albufeira e Olhos de Água
# 64294                           Albufeira e Olhos de Água
# 120664                                     Avenidas Novas
# 82055                           Albufeira e Olhos de Água
# 64229                           Albufeira e Olhos de Água
# 1749                        Bensafrim e Barão de São João
# 109573                                Poceirão e Marateca
# 84705                       Bensafrim e Barão de São João
# 58159                                 Poceirão e Marateca
# 2560                        Bensafrim e Barão de São João
# 84864                       Bensafrim e Barão de São João
# 56                                  Faro (Sé e São Pedro)
# 83681                               Faro (Sé e São Pedro)
# 131114                                  Cascais e Estoril
# 51583                                             Porches
# 82496                                             Porches
# 119623                            Falagueira - Venda Nova
# 58986                                   Cascais e Estoril
# 93403                                   Cascais e Estoril
# 99633                                             Mindelo
# 1838                           São Bartolomeu de Messines
# 60671                                             Mindelo
# 84771                          São Bartolomeu de Messines
# 54315                                   Cascais e Estoril
# 24906                                        Carregueiros
# 106891                                       Carregueiros
# 47733                                        Carregueiros
# 117785   Enxara do Bispo, Gradil e Vila Franca do Rosário
# 127074                                     Avenidas Novas
# 122249                                  Santa Maria Maior
# 88473   Oeiras e São Julião da Barra, Paço de Arcos e ...
# 1855                                                 Guia
# 1356                                             Almancil
# 97349   Sintra (Santa Maria e São Miguel, São Martinho...
# 95994                                        Rio de Mouro
# 45250   Sintra (Santa Maria e São Miguel, São Martinho...
# 134251  Sintra (Santa Maria e São Miguel, São Martinho...
# 84770                                                Guia
# 6556                                              Arroios
# 37636                                        Rio de Mouro
# 83291                                            Almancil
# 117383                                           Vialonga
# 29610                                               Amora
# 38763                                   Cascais e Estoril
# 30349                  Azeitão (São Lourenço e São Simão)
# 118427                 Azeitão (São Lourenço e São Simão)
# 87018                     Figueiró dos Vinhos e Bairradas
# 112231                                              Amora
# 9478                      Figueiró dos Vinhos e Bairradas
# 3866                                             Espinhal
# 80119                                            Espinhal
# 116842                                             Altura
# 110660                                Poceirão e Marateca
# 789                                                Altura
# 32841                                 Poceirão e Marateca
# 129301                                             Altura
# 84752                                              Altura
# 47036   Sintra (Santa Maria e São Miguel, São Martinho...
# 119909                                  Cascais e Estoril
#
#                        Type EnergyCertificate Floor  Parking HasParking  \
# 82054                 Hotel                NC   NaN      1.0        NaN
# 64294                 Hotel                NC   NaN      3.0       True
# 120664             Building                NC   NaN      1.0        NaN
# 82055                 Hotel                NC   NaN      1.0        NaN
# 64229                 Hotel                NC   NaN      3.0       True
# 1749                   Land                NC   NaN      0.0      False
# 109573                 Land                NC   NaN      0.0        NaN
# 84705                  Land                NC   NaN      0.0        NaN
# 58159                  Land                NC   NaN      0.0      False
# 2560             Investment                NC   NaN      0.0      False
# 84864            Investment                NC   NaN      0.0        NaN
# 56                     Land                 D   NaN      0.0      False
# 83681                  Land                 D   NaN      0.0        NaN
# 131114                House                 D   NaN      1.0        NaN
# 51583                 House                 B   NaN      3.0       True
# 82496                 House                 B   NaN      1.0        NaN
# 119623           Investment                NC   NaN      1.0        NaN
# 58986                 House                NC   NaN      3.0       True
# 93403                 House                 A   NaN      0.0        NaN
# 99633                  Land                NC   NaN      0.0        NaN
# 1838                   Farm                NC   NaN      0.0      False
# 60671                  Land                NC   NaN      0.0      False
# 84771                  Farm                NC   NaN      0.0        NaN
# 54315                 House                 A   NaN      3.0       True
# 24906                  Land                NC   NaN      0.0      False
# 106891                 Land                NC   NaN      0.0        NaN
# 47733                  Land                NC   NaN      0.0      False
# 117785                 Farm                 E   NaN      0.0        NaN
# 127074             Building                NC   NaN      1.0        NaN
# 122249                Store                 E   NaN      0.0        NaN
# 88473                 House                NC   NaN      1.0        NaN
# 1855                   Farm                NC   NaN      1.0       True
# 1356                  House                 A   NaN      3.0       True
# 97349                  Land                NC   NaN      0.0        NaN
# 95994             Warehouse                NC   NaN      0.0        NaN
# 45250                  Land                NC   NaN      0.0      False
# 134251              Mansion                 D   NaN      0.0        NaN
# 84770                  Farm                NC   NaN      1.0        NaN
# 6556               Building                 F   NaN      3.0       True
# 37636             Warehouse                NC   NaN      0.0      False
# 83291                 House                 A   NaN      0.0        NaN
# 117383                 Land                NC   NaN      0.0        NaN
# 29610                  Farm                NC   NaN      0.0      False
# 38763                 House                NC   NaN      3.0       True
# 30349                Estate                 C   NaN      0.0      False
# 118427               Estate                 C   NaN      0.0        NaN
# 87018                  Farm                NC   NaN      0.0        NaN
# 112231                 Farm                NC   NaN      0.0        NaN
# 9478                   Farm                NC   NaN      0.0      False
# 3866    Other - Residential                NC   NaN      0.0      False
# 80119   Other - Residential                NC   NaN      0.0        NaN
# 116842                 Land                NC   NaN      0.0        NaN
# 110660               Estate                NC   NaN      0.0        NaN
# 789                    Land                NC   NaN      0.0      False
# 32841                Estate                NC   NaN      0.0      False
# 129301                 Land                NC   NaN      0.0        NaN
# 84752                  Land                NC   NaN      0.0        NaN
# 47036               Mansion                 D   NaN      0.0      False
# 119909                House                 A   NaN      1.0        NaN
#
#         ConstructionYear    TotalArea  GrossArea EnergyEfficiencyLevel  \
# 82054             2001.0       6382.0        NaN                    NC
# 64294             2001.0      47054.0        NaN                   NaN
# 120664            2024.0       2877.0        NaN                    NC
# 82055             2005.0       1828.0        NaN                    NC
# 64229             2005.0      21300.0        NaN                   NaN
# 1749                 NaN     490807.0        NaN                   NaN
# 109573               NaN          NaN        NaN                    NC
# 84705                NaN     490807.0        NaN                    NC
# 58159                NaN  165620600.0        NaN                   NaN
# 2560                 NaN    2716250.0  2716250.0                   NaN
# 84864                NaN    2716250.0        NaN                    NC
# 56                   NaN      45400.0        NaN                   NaN
# 83681                NaN          NaN        NaN                     D
# 131114            1923.0        912.0        NaN                     D
# 51583             1980.0          0.0    15770.0                   NaN
# 82496             1980.0        845.0        NaN                     B
# 119623               NaN      13500.0        NaN                    NC
# 58986                NaN       1346.0        NaN                   NaN
# 93403             2011.0        495.0        NaN                     A
# 99633                NaN          NaN        NaN                    NC
# 1838              1950.0     803240.0        NaN                   NaN
# 60671                NaN      30830.0        NaN                   NaN
# 84771             1950.0        360.0        NaN                    NC
# 54315             2011.0       3320.0      794.0                   NaN
# 24906                NaN    1372730.0        NaN                   NaN
# 106891            1988.0          NaN        NaN                    NC
# 47733             1988.0    1372730.0        NaN                   NaN
# 117785               NaN       3500.0        NaN                     E
# 127074               NaN        982.0        NaN                    NC
# 122249               NaN       1030.0        NaN                     E
# 88473                NaN       1709.0        NaN                    NC
# 1855              1950.0     101520.0        NaN                   NaN
# 1356                 NaN       1897.0        NaN                   NaN
# 97349                NaN          NaN        NaN                    NC
# 95994                NaN        400.0        NaN                    NC
# 45250                NaN     482200.0        NaN                   NaN
# 134251            1921.0       1249.0        NaN                     D
# 84770             1950.0       2000.0        NaN                    NC
# 6556              1975.0       1827.0        NaN                   NaN
# 37636                NaN      55000.0      400.0                   NaN
# 83291             2024.0       1897.0        NaN                     A
# 117383               NaN      25240.0        NaN                    NC
# 29610             1937.0     144080.0        NaN                   NaN
# 38763                NaN       1346.0        NaN                   NaN
# 30349                NaN     400000.0        NaN                   NaN
# 118427               NaN       3200.0        NaN                     C
# 87018                NaN     249740.0        NaN                    NC
# 112231            1937.0        288.0        NaN                    NC
# 9478                 NaN     249740.0        NaN                   NaN
# 3866                 NaN    3000000.0        NaN                   NaN
# 80119                NaN       7500.0        NaN                    NC
# 116842            1987.0        825.0        NaN                    NC
# 110660               NaN    1020000.0        NaN                    NC
# 789               1987.0     178198.0      825.0                   NaN
# 32841                NaN    1020000.0        NaN                   NaN
# 129301            1987.0        825.0        NaN                    NC
# 84752             1987.0        825.0        NaN                    NC
# 47036             1921.0       6245.0     1249.0                   NaN
# 119909            2024.0       2059.0        NaN                     A
#
#                     PublishDate Garage Elevator ElectricCarsCharging  \
# 82054   2024-09-02 16:00:34.667  False     True                 True
# 64294                       NaN    NaN     True                  NaN
# 120664  2024-11-15 10:26:01.167  False    False                 True
# 82055   2024-09-02 16:02:48.580  False     True                 True
# 64229                       NaN    NaN     True                  NaN
# 1749                        NaN    NaN    False                  NaN
# 109573  2024-07-31 08:31:04.557  False    False                False
# 84705                       NaN  False    False                False
# 58159                       NaN    NaN    False                  NaN
# 2560                        NaN    NaN    False                  NaN
# 84864                       NaN  False    False                False
# 56                          NaN    NaN    False                  NaN
# 83681                       NaN  False    False                False
# 131114  2025-01-09 17:17:18.087  False     True                False
# 51583                       NaN    NaN    False                  NaN
# 82496                       NaN  False    False                False
# 119623                      NaN  False    False                False
# 58986                       NaN    NaN    False                  NaN
# 93403                       NaN   True     True                False
# 99633   2024-08-16 17:27:37.217  False    False                False
# 1838                        NaN    NaN    False                  NaN
# 60671                       NaN    NaN    False                  NaN
# 84771                       NaN  False    False                False
# 54315                       NaN    NaN     True                  NaN
# 24906                       NaN    NaN    False                  NaN
# 106891  2024-06-11 13:47:00.417  False    False                False
# 47733                       NaN    NaN    False                  NaN
# 117785                      NaN   True    False                False
# 127074  2024-12-17 15:34:52.363  False     True                False
# 122249                      NaN  False     True                False
# 88473   2024-10-14 09:26:53.097  False    False                False
# 1855                        NaN    NaN    False                  NaN
# 1356                        NaN    NaN     True                  NaN
# 97349                       NaN  False    False                False
# 95994                       NaN  False    False                False
# 45250                       NaN    NaN    False                  NaN
# 134251  2025-01-23 14:55:05.413  False    False                False
# 84770                       NaN  False    False                False
# 6556                        NaN    NaN     True                  NaN
# 37636                       NaN    NaN    False                  NaN
# 83291                       NaN   True     True                 True
# 117383  2024-10-31 10:53:42.127  False    False                False
# 29610                       NaN    NaN    False                  NaN
# 38763                       NaN    NaN    False                  NaN
# 30349                       NaN    NaN    False                  NaN
# 118427                      NaN  False    False                False
# 87018                       NaN  False    False                False
# 112231                      NaN  False    False                False
# 9478                        NaN    NaN    False                  NaN
# 3866                        NaN    NaN    False                  NaN
# 80119                       NaN  False    False                False
# 116842                      NaN  False    False                False
# 110660  2024-03-26 12:07:13.833  False    False                False
# 789                         NaN    NaN    False                  NaN
# 32841                       NaN    NaN    False                  NaN
# 129301                      NaN  False    False                False
# 84752                       NaN  False    False                False
# 47036                       NaN    NaN    False                  NaN
# 119909                      NaN  False    False                False
#
#         TotalRooms  NumberOfBedrooms  NumberOfWC ConservationStatus  \
# 82054          NaN               NaN         NaN                NaN
# 64294          NaN               NaN         NaN                NaN
# 120664         NaN               NaN         NaN                NaN
# 82055          NaN               NaN         NaN                NaN
# 64229          NaN               NaN         NaN                NaN
# 1749           0.0               NaN         NaN                NaN
# 109573         NaN               NaN         0.0                NaN
# 84705          0.0               0.0         0.0                NaN
# 58159          NaN               NaN         NaN                NaN
# 2560           0.0               NaN         NaN                NaN
# 84864          0.0               0.0         0.0                NaN
# 56             NaN               NaN         NaN                NaN
# 83681          0.0               NaN         0.0                NaN
# 131114        11.0              11.0         0.0                NaN
# 51583          8.0               NaN         NaN                NaN
# 82496          8.0               8.0         0.0                NaN
# 119623         NaN               NaN         0.0                NaN
# 58986          5.0               NaN         NaN                NaN
# 93403          6.0               5.0         0.0                NaN
# 99633          NaN               NaN         NaN                NaN
# 1838           1.0               NaN         NaN                NaN
# 60671          NaN               NaN         NaN                NaN
# 84771          1.0               1.0         0.0                NaN
# 54315          5.0               NaN         NaN                NaN
# 24906          NaN               NaN         NaN                NaN
# 106891         NaN               NaN         0.0                NaN
# 47733          NaN               NaN         NaN                NaN
# 117785        20.0               8.0         0.0                NaN
# 127074         NaN               NaN         0.0                NaN
# 122249         9.0               0.0         6.0               Used
# 88473         40.0               7.0         1.0                NaN
# 1855           NaN               NaN         NaN                NaN
# 1356           5.0               NaN         NaN                NaN
# 97349         22.0               NaN         0.0                NaN
# 95994          NaN               NaN         0.0                NaN
# 45250          NaN               NaN         NaN                NaN
# 134251        14.0               9.0         3.0                NaN
# 84770         39.0               NaN         0.0                NaN
# 6556           NaN               NaN         NaN                NaN
# 37636          NaN               NaN         NaN                NaN
# 83291          9.0               5.0         2.0                New
# 117383         NaN               NaN         NaN                NaN
# 29610          6.0               NaN         NaN                NaN
# 38763          5.0               NaN         NaN                NaN
# 30349          9.0               NaN         NaN                NaN
# 118427        18.0               9.0         1.0                NaN
# 87018          NaN               NaN         0.0                NaN
# 112231         7.0               6.0         0.0                NaN
# 9478           NaN               NaN         NaN                NaN
# 3866           NaN               NaN         NaN                NaN
# 80119          NaN               NaN         0.0                NaN
# 116842        12.0               0.0         0.0                NaN
# 110660         NaN               NaN         NaN                NaN
# 789            0.0               NaN         NaN                NaN
# 32841          NaN               NaN         NaN                NaN
# 129301        12.0               0.0         0.0                NaN
# 84752         12.0               0.0         0.0                NaN
# 47036          9.0               NaN         NaN                NaN
# 119909         7.0               6.0         8.0                NaN
#
#         LivingArea      LotSize   BuiltArea  NumberOfBathrooms
# 82054       6382.0      47054.0         NaN                NaN
# 64294       6382.0          NaN         NaN                NaN
# 120664      2877.0          NaN     2877.00                NaN
# 82055       1828.0      21300.0         NaN                NaN
# 64229       1828.0          NaN         NaN                NaN
# 1749           NaN          NaN         NaN                0.0
# 109573         NaN  165620600.0         NaN                0.0
# 84705          NaN     490807.0         NaN                0.0
# 58159          NaN          NaN         NaN                0.0
# 2560           NaN          NaN         NaN                0.0
# 84864          NaN    2716250.0  2716250.00                0.0
# 56             NaN          NaN         NaN                0.0
# 83681          NaN      45400.0         NaN                0.0
# 131114       820.0       2690.0     1316.86                6.0
# 51583        760.0          NaN         NaN                NaN
# 82496        760.0          0.0    15770.00               12.0
# 119623         NaN          NaN         NaN                0.0
# 58986        703.0          NaN         NaN                6.0
# 93403        446.0       3320.0      794.00                7.0
# 99633          NaN      30830.0         NaN                NaN
# 1838         360.0          NaN         NaN                0.0
# 60671          NaN          NaN         NaN                NaN
# 84771        360.0     803240.0         NaN                0.0
# 54315        446.0          NaN         NaN                7.0
# 24906          NaN          NaN         NaN                0.0
# 106891         NaN    1372730.0         NaN                0.0
# 47733          NaN          NaN         NaN                0.0
# 117785      3150.0    1200000.0         NaN                8.0
# 127074       982.0          NaN      982.00                0.0
# 122249       950.0        480.0     1030.83               10.0
# 88473       1709.0       5600.0         NaN                6.0
# 1855        2000.0          NaN         NaN                NaN
# 1356         637.0          NaN         NaN                6.0
# 97349          NaN     482200.0         NaN                0.0
# 95994        400.0      55000.0      400.00                0.0
# 45250          NaN          NaN         NaN                0.0
# 134251      1150.0       6245.0     1249.00                6.0
# 84770       2000.0     101520.0         NaN               39.0
# 6556         236.0          NaN         NaN                0.0
# 37636        400.0          NaN         NaN                0.0
# 83291        637.0          NaN         NaN                6.0
# 117383     25240.0      25240.0    25240.00                NaN
# 29610        288.0          NaN         NaN                3.0
# 38763        703.0          NaN         NaN                6.0
# 30349          NaN          NaN         NaN                4.0
# 118427         NaN     400000.0         NaN                4.0
# 87018     249740.0     249740.0         NaN                0.0
# 112231       288.0     144080.0         NaN                3.0
# 9478      249740.0          NaN         NaN                0.0
# 3866           NaN          NaN         NaN                0.0
# 80119          NaN    3000000.0         NaN                0.0
# 116842         NaN     178198.0      825.31                6.0
# 110660         NaN          NaN         NaN                5.0
# 789            NaN          NaN         NaN                6.0
# 32841          NaN          NaN         NaN                5.0
# 129301         NaN     178198.0      825.31                6.0
# 84752          NaN     178198.0      825.31                6.0
# 47036       1150.0          NaN         NaN                6.0
# 119909      1199.0       2616.0     2446.00                8.0

# %%
num_cols = df.select_dtypes(include=[np.number]).columns

for i in num_cols:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# TotalArea, GrossArea, TotalRooms, LotSize, BuiltArea

# %%
df = df.drop(index=df[df['TotalArea'] > 5000000000].index)
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [135234 rows x 25 columns]

# %%
sns.boxplot(df['TotalArea'])
# Out:
# <Axes: ylabel='TotalArea'>

# %%
df = df.drop(index=df[df['TotalArea'] == df['TotalArea'].max()].index)

# %%
sns.boxplot(df['TotalArea'])
# Out:
# <Axes: ylabel='TotalArea'>

# %%
sns.boxplot(df['GrossArea'])
# Out:
# <Axes: ylabel='GrossArea'>

# %%
df = df.drop(index=df[df['GrossArea'] > 10000000].index)

# %%
sns.boxplot(df['GrossArea'])
# Out:
# <Axes: ylabel='GrossArea'>

# %%
df.sort_values(by='GrossArea', ascending=False)
# Out:
#              Price    District         City                           Town  \
# 44294    3975000.0  Portalegre         Avis                   Aldeia Velha
# 2560    19500000.0        Faro        Lagos  Bensafrim e Barão de São João
# 55671    9950000.0        Faro       Silves                         Silves
# 44361    5700000.0  Portalegre  Campo Maior               São João Batista
# 2504     6000000.0        Faro       Silves                         Silves
# ...            ...         ...          ...                            ...
# 135531    349900.0   Vila Real     Valpaços             Valpaços e Sanfins
# 135532     77500.0   Vila Real   Montalegre                          Salto
# 135533     50000.0   Vila Real        Alijó                Castedo e Cotas
# 135534     36000.0   Vila Real      Sabrosa                          Paços
# 135535     35000.0   Vila Real     Valpaços                        Algeriz
#
#               Type EnergyCertificate Floor  Parking HasParking  \
# 44294       Estate                NC   NaN      0.0      False
# 2560    Investment                NC   NaN      0.0      False
# 55671         Farm                 D   NaN      0.0      False
# 44361       Estate                NC   NaN      0.0      False
# 2504          Farm                NC   NaN      3.0       True
# ...            ...               ...   ...      ...        ...
# 135531       House                 F   NaN      1.0        NaN
# 135532   Apartment                NC   NaN      0.0        NaN
# 135533       House                NC   NaN      1.0        NaN
# 135534        Land                NC   NaN      0.0        NaN
# 135535        Land                NC   NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 44294             1961.0  3770000.0  3770000.0                   NaN
# 2560                 NaN  2716250.0  2716250.0                   NaN
# 55671                NaN     1036.0  2181280.0                   NaN
# 44361                NaN  2135000.0  2135000.0                   NaN
# 2504                 NaN  1733080.0  1733080.0                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 44294                   NaN    NaN    False                  NaN         NaN
# 2560                    NaN    NaN    False                  NaN         0.0
# 55671                   NaN    NaN    False                  NaN         NaN
# 44361                   NaN    NaN    False                  NaN         NaN
# 2504                    NaN    NaN    False                  NaN         NaN
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 44294                NaN         NaN                NaN   3770000.0      NaN
# 2560                 NaN         NaN                NaN         NaN      NaN
# 55671                NaN         NaN                NaN         NaN      NaN
# 44361                NaN         NaN                NaN         NaN      NaN
# 2504                 NaN         NaN                NaN      1280.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 44294         NaN                0.0
# 2560          NaN                0.0
# 55671         NaN                NaN
# 44361         NaN                0.0
# 2504          NaN                0.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [135230 rows x 25 columns]

# %%
sns.boxplot(df['TotalRooms'])
# Out:
# <Axes: ylabel='TotalRooms'>

# %%
df = df.drop(index=df[df['TotalRooms'] > 1000].index)

# %%
sns.boxplot(df['TotalRooms'])
# Out:
# <Axes: ylabel='TotalRooms'>

# %%
df.sort_values(by='NumberOfBedrooms', ascending=False)
# Out:
#             Price   District             City  \
# 105319  3000000.0      Porto  Póvoa de Varzim
# 89681   8000000.0     Lisboa           Lisboa
# 127240  3000000.0     Lisboa           Lisboa
# 127177  2400000.0    Setúbal           Almada
# 70571   2250000.0     Aveiro             Ovar
# ...           ...        ...              ...
# 135521   537500.0    Setúbal   Alcácer do Sal
# 135527   990000.0    Setúbal           Almada
# 135528   130000.0    Setúbal          Palmela
# 135534    36000.0  Vila Real          Sabrosa
# 135535    35000.0  Vila Real         Valpaços
#
#                                                      Town                Type  \
# 105319                                             Estela               Hotel
# 89681                                   Santa Maria Maior            Building
# 127240                                  Santa Maria Maior            Building
# 127177                     Charneca de Caparica e Sobreda  Other - Commercial
# 70571   Ovar, São João, Arada e São Vicente de Pereira...               Hotel
# ...                                                   ...                 ...
# 135521  Alcácer do Sal (Santa Maria do Castelo e Santi...            Building
# 135527         Almada, Cova da Piedade, Pragal e Cacilhas            Building
# 135528                                            Palmela                Land
# 135534                                              Paços                Land
# 135535                                            Algeriz                Land
#
#        EnergyCertificate Floor  Parking HasParking  ConstructionYear  \
# 105319                 C   NaN      1.0        NaN            1995.0
# 89681                 NC   NaN      1.0        NaN            1972.0
# 127240                 D   NaN      0.0        NaN               NaN
# 127177                 C   NaN      1.0        NaN            2014.0
# 70571                 NC   NaN      0.0        NaN            1990.0
# ...                  ...   ...      ...        ...               ...
# 135521                 D   NaN      0.0        NaN            1988.0
# 135527                NC   NaN      0.0        NaN            1961.0
# 135528                NC   NaN      0.0        NaN               NaN
# 135534                NC   NaN      0.0        NaN               NaN
# 135535                NC   NaN      0.0        NaN               NaN
#
#         TotalArea  GrossArea EnergyEfficiencyLevel              PublishDate  \
# 105319     2832.0        NaN                     C                      NaN
# 89681       840.0        NaN                    NC                      NaN
# 127240      824.0        NaN                     D  2024-12-19 17:27:17.213
# 127177     1182.0        NaN                     C  2024-12-18 16:56:50.507
# 70571      3750.0        NaN                    NC                      NaN
# ...           ...        ...                   ...                      ...
# 135521      156.0        NaN                     D                      NaN
# 135527      564.0        NaN                    NC      2024-06-26 09:32:13
# 135528     1189.0        NaN                    NC      2021-08-19 15:22:16
# 135534       90.0        NaN                    NC      2022-07-07 16:06:50
# 135535      100.0        NaN                    NC      2023-01-05 15:37:09
#
#        Garage Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 105319  False     True                False         NaN              21.0
# 89681   False     True                False         NaN              21.0
# 127240  False    False                False        24.0              21.0
# 127177  False     True                False        21.0              21.0
# 70571    True     True                False         NaN              21.0
# ...       ...      ...                  ...         ...               ...
# 135521  False    False                False         NaN               NaN
# 135527  False    False                False         NaN               NaN
# 135528  False    False                False         NaN               NaN
# 135534  False    False                False         NaN               NaN
# 135535  False    False                False         NaN               NaN
#
#         NumberOfWC ConservationStatus  LivingArea  LotSize  BuiltArea  \
# 105319         8.0                NaN      2832.0   4300.0    2832.40
# 89681          0.0                NaN       714.0    184.0        NaN
# 127240         0.0                NaN       741.0    461.0     824.11
# 127177         0.0                NaN       849.0   2075.0        NaN
# 70571          1.0                NaN      3750.0   2192.0    1667.00
# ...            ...                ...         ...      ...        ...
# 135521         0.0                NaN       156.0     58.0        NaN
# 135527         0.0                NaN       563.0      NaN        NaN
# 135528         0.0                NaN         NaN   1189.0        NaN
# 135534         0.0                NaN         NaN    300.0     240.88
# 135535         0.0                NaN         NaN    100.0        NaN
#
#         NumberOfBathrooms
# 105319               58.0
# 89681                23.0
# 127240                2.0
# 127177               26.0
# 70571                61.0
# ...                   ...
# 135521                0.0
# 135527                0.0
# 135528                0.0
# 135534                0.0
# 135535                0.0
#
# [135229 rows x 25 columns]

# %%
df[df['NumberOfWC'] < 0]
# Out:
#            Price District    City            Town       Type  \
# 94946  1250000.0   Lisboa  Lisboa  Avenidas Novas  Apartment
#
#       EnergyCertificate Floor  Parking HasParking  ConstructionYear  \
# 94946                NC   NaN      0.0        NaN               NaN
#
#        TotalArea  GrossArea EnergyEfficiencyLevel PublishDate Garage Elevator  \
# 94946      133.0        NaN                    NC         NaN   True     True
#
#       ElectricCarsCharging  TotalRooms  NumberOfBedrooms  NumberOfWC  \
# 94946                False         3.0               2.0       -15.0
#
#       ConservationStatus  LivingArea  LotSize  BuiltArea  NumberOfBathrooms
# 94946                New       127.0      NaN        NaN              -13.0

# %%
df = df.drop(index=df[df['NumberOfWC'] < 0].index)

# %%
sns.boxplot(df['NumberOfWC'])
# Out:
# <Axes: ylabel='NumberOfWC'>

# %%
df.sort_values(by='NumberOfWC', ascending=False)
# Out:
#             Price          District              City  \
# 94949   1700000.0            Lisboa            Lisboa
# 95393   4000000.0            Lisboa            Lisboa
# 87142    850000.0            Leiria  Caldas da Rainha
# 113134  1980000.0  Viana do Castelo           Valença
# 80569   1200000.0           Coimbra   Figueira da Foz
# ...           ...               ...               ...
# 135515    60000.0           Setúbal           Montijo
# 135520   950000.0           Setúbal             Moita
# 135524   280000.0           Setúbal           Montijo
# 135525   395000.0           Setúbal         Alcochete
# 135532    77500.0         Vila Real        Montalegre
#
#                                                      Town  \
# 94949                                      Avenidas Novas
# 95393                                             Olivais
# 87142   Caldas da Rainha - Nossa Senhora do Pópulo, Co...
# 113134                                     Gandra e Taião
# 80569                                Buarcos e São Julião
# ...                                                   ...
# 135515                                             Pegões
# 135520                                       Alhos Vedros
# 135524                               Montijo e Afonsoeiro
# 135525                                          Alcochete
# 135532                                              Salto
#
#                        Type EnergyCertificate Floor  Parking HasParking  \
# 94949             Apartment                NC   NaN      0.0        NaN
# 95393              Building                NC   NaN      0.0        NaN
# 87142   Other - Residential                NC   NaN      0.0        NaN
# 113134                Hotel                 C   NaN      1.0        NaN
# 80569                 Hotel                NC   NaN      0.0        NaN
# ...                     ...               ...   ...      ...        ...
# 135515                 Land                NC   NaN      0.0        NaN
# 135520           Industrial                NC   NaN      0.0        NaN
# 135524                House                 E   NaN      0.0        NaN
# 135525            Apartment                 D   NaN      0.0        NaN
# 135532            Apartment                NC   NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 94949                NaN      176.0        NaN                    NC
# 95393             1949.0     3278.0        NaN                    NC
# 87142                NaN      812.0        NaN                    NC
# 113134            2007.0     3051.0        NaN                     C
# 80569             1946.0     1510.0        NaN                    NC
# ...                  ...        ...        ...                   ...
# 135515               NaN        NaN        NaN                    NC
# 135520               NaN     5280.0        NaN                    NC
# 135524            1971.0       27.0        NaN                     E
# 135525            2003.0      232.0        NaN                     D
# 135532            2010.0       39.0        NaN                    NC
#
#        PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 94949          NaN   True     True                False         5.0
# 95393          NaN  False    False                False         NaN
# 87142          NaN  False     True                False        49.0
# 113134         NaN  False     True                False        37.0
# 80569          NaN   True    False                False        35.0
# ...            ...    ...      ...                  ...         ...
# 135515         NaN  False    False                False         NaN
# 135520         NaN  False    False                False         NaN
# 135524         NaN   True    False                False         NaN
# 135525         NaN  False     True                False         NaN
# 135532         NaN   True    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 94949                4.0        59.0                New       168.0      NaN
# 95393               21.0        40.0   Needs renovation      3278.0      NaN
# 87142               21.0        40.0                NaN         NaN      NaN
# 113134              21.0        37.0                NaN         NaN   9500.0
# 80569               21.0        35.0               Used         NaN   1267.0
# ...                  ...         ...                ...         ...      ...
# 135515               NaN         NaN                NaN         NaN    252.0
# 135520               NaN         NaN                NaN         NaN      NaN
# 135524               2.0         NaN                NaN        27.0    400.0
# 135525               4.0         NaN     Good condition       119.0    232.0
# 135532               1.0         NaN                New        39.0      NaN
#
#         BuiltArea  NumberOfBathrooms
# 94949         NaN               62.0
# 95393      3278.0               40.0
# 87142         NaN               40.0
# 113134     3436.0               37.0
# 80569         NaN               35.0
# ...           ...                ...
# 135515        NaN                NaN
# 135520        NaN                NaN
# 135524        NaN                2.0
# 135525        NaN                2.0
# 135532       60.0                1.0
#
# [135228 rows x 25 columns]

# %%
df = df.drop(index=94949)

# %%
sns.boxplot(df['NumberOfWC'])
# Out:
# <Axes: ylabel='NumberOfWC'>

# %%
sns.boxplot(df['LotSize'])
# Out:
# <Axes: ylabel='LotSize'>

# %%
df.sort_values(by='LotSize', ascending=False)
# Out:
#              Price          District               City  \
# 109573  20000000.0           Setúbal            Palmela
# 80278     315000.0           Coimbra            Coimbra
# 71118    1280000.0              Beja            Odemira
# 74533     850000.0          Bragança          Mirandela
# 75908     850000.0          Bragança          Mirandela
# ...            ...               ...                ...
# 135520    950000.0           Setúbal              Moita
# 135527    990000.0           Setúbal             Almada
# 135530    155000.0  Viana do Castelo  Arcos de Valdevez
# 135532     77500.0         Vila Real         Montalegre
# 135533     50000.0         Vila Real              Alijó
#
#                                               Town        Type  \
# 109573                         Poceirão e Marateca        Land
# 80278                                São Silvestre        Farm
# 71118                                    Relíquias        Land
# 74533                                       Múrias        Farm
# 75908                                       Múrias        Farm
# ...                                            ...         ...
# 135520                                Alhos Vedros  Industrial
# 135527  Almada, Cova da Piedade, Pragal e Cacilhas    Building
# 135530                                        Paçô   Apartment
# 135532                                       Salto   Apartment
# 135533                             Castedo e Cotas       House
#
#        EnergyCertificate Floor  Parking HasParking  ConstructionYear  \
# 109573                NC   NaN      0.0        NaN               NaN
# 80278                 NC   NaN      0.0        NaN               NaN
# 71118                  F   NaN      0.0        NaN               NaN
# 74533                  D   NaN      0.0        NaN               NaN
# 75908                  D   NaN      0.0        NaN               NaN
# ...                  ...   ...      ...        ...               ...
# 135520                NC   NaN      0.0        NaN               NaN
# 135527                NC   NaN      0.0        NaN            1961.0
# 135530                 E   NaN      1.0        NaN            2000.0
# 135532                NC   NaN      0.0        NaN            2010.0
# 135533                NC   NaN      1.0        NaN            1987.0
#
#           TotalArea  GrossArea EnergyEfficiencyLevel              PublishDate  \
# 109573          NaN        NaN                    NC  2024-07-31 08:31:04.557
# 80278         300.0        NaN                    NC                      NaN
# 71118   131699000.0        NaN                     F                      NaN
# 74533         742.0        NaN                     D                      NaN
# 75908         742.0        NaN                     D                      NaN
# ...             ...        ...                   ...                      ...
# 135520       5280.0        NaN                    NC                      NaN
# 135527        564.0        NaN                    NC      2024-06-26 09:32:13
# 135530         87.0        NaN                     E      2025-01-14 15:14:02
# 135532         39.0        NaN                    NC                      NaN
# 135533         69.0        NaN                    NC                      NaN
#
#        Garage Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 109573  False    False                False         NaN               NaN
# 80278   False    False                False         NaN               NaN
# 71118   False    False                False         4.0               NaN
# 74533    True    False                False         NaN               6.0
# 75908    True    False                False         NaN               6.0
# ...       ...      ...                  ...         ...               ...
# 135520  False    False                False         NaN               NaN
# 135527  False    False                False         NaN               NaN
# 135530  False    False                False         NaN               2.0
# 135532   True    False                False         NaN               1.0
# 135533  False    False                False         NaN               2.0
#
#         NumberOfWC ConservationStatus  LivingArea      LotSize  BuiltArea  \
# 109573         0.0                NaN         NaN  165620600.0        NaN
# 80278          0.0   Needs renovation       300.0  138836800.0        NaN
# 71118          0.0                NaN       263.0  131699000.0        NaN
# 74533          0.0                NaN         NaN  100000000.0        NaN
# 75908          0.0                NaN         NaN  100000000.0        NaN
# ...            ...                ...         ...          ...        ...
# 135520         NaN                NaN         NaN          NaN        NaN
# 135527         0.0                NaN       563.0          NaN        NaN
# 135530         0.0                NaN        87.0          NaN        NaN
# 135532         NaN                New        39.0          NaN       60.0
# 135533         1.0                NaN        84.0          NaN       84.5
#
#         NumberOfBathrooms
# 109573                0.0
# 80278                 0.0
# 71118                 0.0
# 74533                 6.0
# 75908                 6.0
# ...                   ...
# 135520                NaN
# 135527                0.0
# 135530                1.0
# 135532                1.0
# 135533                2.0
#
# [135227 rows x 25 columns]

# %%
df = df.drop(index=109573)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [126330 rows x 25 columns]

# %%
sns.boxplot(df['BuiltArea'])
# Out:
# <Axes: ylabel='BuiltArea'>

# %%
df.sort_values(by='BuiltArea', ascending=False)
# Out:
#              Price          District               City  \
# 73423     775000.0             Braga              Braga
# 69628    2200000.0            Aveiro             Águeda
# 98256    3975000.0        Portalegre               Avis
# 84864   19500000.0              Faro              Lagos
# 134345   1099500.0             Évora       Vendas Novas
# ...            ...               ...                ...
# 135527    990000.0           Setúbal             Almada
# 135528    130000.0           Setúbal            Palmela
# 135529     45000.0  Viana do Castelo      Ponte de Lima
# 135530    155000.0  Viana do Castelo  Arcos de Valdevez
# 135535     35000.0         Vila Real           Valpaços
#
#                                               Town        Type  \
# 73423                                       Tebosa  Industrial
# 69628                               Aguada de Cima   Warehouse
# 98256                                 Aldeia Velha      Estate
# 84864                Bensafrim e Barão de São João  Investment
# 134345                                Vendas Novas        Land
# ...                                            ...         ...
# 135527  Almada, Cova da Piedade, Pragal e Cacilhas    Building
# 135528                                     Palmela        Land
# 135529                                     Labruja       House
# 135530                                        Paçô   Apartment
# 135535                                     Algeriz        Land
#
#        EnergyCertificate Floor  Parking HasParking  ConstructionYear  \
# 73423                 NC   NaN      0.0        NaN               NaN
# 69628                 NC   NaN      0.0        NaN            2010.0
# 98256                 NC   NaN      0.0        NaN            1961.0
# 84864                 NC   NaN      0.0        NaN               NaN
# 134345                NC   NaN      0.0        NaN               NaN
# ...                  ...   ...      ...        ...               ...
# 135527                NC   NaN      0.0        NaN            1961.0
# 135528                NC   NaN      0.0        NaN               NaN
# 135529                NC   NaN      1.0        NaN            1937.0
# 135530                 E   NaN      1.0        NaN            2000.0
# 135535                NC   NaN      0.0        NaN               NaN
#
#          TotalArea  GrossArea EnergyEfficiencyLevel              PublishDate  \
# 73423   12750000.0        NaN                    NC  2024-02-12 19:29:21.207
# 69628    3442000.0        NaN                    NC  2024-01-30 18:20:50.550
# 98256    3770000.0        NaN                    NC                      NaN
# 84864    2716250.0        NaN                    NC                      NaN
# 134345   2417260.0        NaN                    NC  2025-01-24 12:22:05.127
# ...            ...        ...                   ...                      ...
# 135527       564.0        NaN                    NC      2024-06-26 09:32:13
# 135528      1189.0        NaN                    NC      2021-08-19 15:22:16
# 135529       374.0        NaN                    NC                      NaN
# 135530        87.0        NaN                     E      2025-01-14 15:14:02
# 135535       100.0        NaN                    NC      2023-01-05 15:37:09
#
#        Garage Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 73423   False    False                False         NaN               NaN
# 69628   False    False                False         NaN               NaN
# 98256   False    False                False         NaN               NaN
# 84864   False    False                False         0.0               0.0
# 134345  False    False                False         NaN               NaN
# ...       ...      ...                  ...         ...               ...
# 135527  False    False                False         NaN               NaN
# 135528  False    False                False         NaN               NaN
# 135529  False    False                False         NaN               0.0
# 135530  False    False                False         NaN               2.0
# 135535  False    False                False         NaN               NaN
#
#         NumberOfWC ConservationStatus  LivingArea     LotSize   BuiltArea  \
# 73423          NaN                NaN         NaN  12750000.0  12750000.0
# 69628          0.0               Used   5429000.0   5732000.0  12650000.0
# 98256          0.0                NaN   3770000.0   3770000.0   3770000.0
# 84864          0.0                NaN         NaN   2716250.0   2716250.0
# 134345         NaN                NaN         NaN   2500000.0   2417260.0
# ...            ...                ...         ...         ...         ...
# 135527         0.0                NaN       563.0         NaN         NaN
# 135528         0.0                NaN         NaN      1189.0         NaN
# 135529         0.0                NaN       374.0      4370.0         NaN
# 135530         0.0                NaN        87.0         NaN         NaN
# 135535         0.0                NaN         NaN       100.0         NaN
#
#         NumberOfBathrooms
# 73423                 NaN
# 69628                 0.0
# 98256                 0.0
# 84864                 0.0
# 134345                NaN
# ...                   ...
# 135527                0.0
# 135528                0.0
# 135529                0.0
# 135530                1.0
# 135535                0.0
#
# [126330 rows x 25 columns]

# %%
df = df.drop(index=[73423, 69628])

# %%
sns.boxplot(df['BuiltArea'])
# Out:
# <Axes: ylabel='BuiltArea'>

# %%
df.sort_values(by='NumberOfBathrooms', ascending=False)
# Out:
#             Price    District               City  \
# 135120    55000.0  Portalegre      Alter do Chão
# 86150   6800000.0      Leiria   Caldas da Rainha
# 102894  1900000.0       Porto  Paços de Ferreira
# 70571   2250000.0      Aveiro               Ovar
# 105319  3000000.0       Porto    Póvoa de Varzim
# ...           ...         ...                ...
# 135506   800000.0     Setúbal            Setúbal
# 135508    12500.0     Setúbal            Setúbal
# 135512   100000.0     Setúbal            Palmela
# 135515    60000.0     Setúbal            Montijo
# 135520   950000.0     Setúbal              Moita
#
#                                                      Town                Type  \
# 135120                                           Cunheira               House
# 86150   Caldas da Rainha - Nossa Senhora do Pópulo, Co...               Hotel
# 102894                                              Seroa  Other - Commercial
# 70571   Ovar, São João, Arada e São Vicente de Pereira...               Hotel
# 105319                                             Estela               Hotel
# ...                                                   ...                 ...
# 135506                                      São Sebastião           Warehouse
# 135508                                      São Sebastião              Garage
# 135512                                        Pinhal Novo                Land
# 135515                                             Pegões                Land
# 135520                                       Alhos Vedros          Industrial
#
#        EnergyCertificate Floor  Parking HasParking  ConstructionYear  \
# 135120                NC   NaN      0.0        NaN            1970.0
# 86150                  C   NaN      1.0        NaN            1992.0
# 102894                 D   NaN      0.0        NaN            2010.0
# 70571                 NC   NaN      0.0        NaN            1990.0
# 105319                 C   NaN      1.0        NaN            1995.0
# ...                  ...   ...      ...        ...               ...
# 135506                NC   NaN      0.0        NaN            1990.0
# 135508                NC   NaN      0.0        NaN            2007.0
# 135512                NC   NaN      0.0        NaN               NaN
# 135515                NC   NaN      0.0        NaN               NaN
# 135520                NC   NaN      0.0        NaN               NaN
#
#         TotalArea  GrossArea EnergyEfficiencyLevel              PublishDate  \
# 135120       41.0        NaN                    NC  2025-01-23 17:19:52.243
# 86150      4845.0        NaN                     C                      NaN
# 102894     2200.0        NaN                     D                      NaN
# 70571      3750.0        NaN                    NC                      NaN
# 105319     2832.0        NaN                     C                      NaN
# ...           ...        ...                   ...                      ...
# 135506     1120.0        NaN                    NC                      NaN
# 135508       15.0        NaN                    NC                      NaN
# 135512      568.0        NaN                    NC                      NaN
# 135515        NaN        NaN                    NC                      NaN
# 135520     5280.0        NaN                    NC                      NaN
#
#        Garage Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 135120  False    False                False         2.0               1.0
# 86150   False     True                False        97.0              21.0
# 102894   True     True                 True        80.0               NaN
# 70571    True     True                False         NaN              21.0
# 105319  False     True                False         NaN              21.0
# ...       ...      ...                  ...         ...               ...
# 135506  False    False                False         NaN               0.0
# 135508  False    False                False         NaN               NaN
# 135512  False    False                False         NaN               NaN
# 135515  False    False                False         NaN               NaN
# 135520  False    False                False         NaN               NaN
#
#         NumberOfWC ConservationStatus  LivingArea  LotSize  BuiltArea  \
# 135120         1.0                NaN       100.0    101.0      130.0
# 86150          0.0     Good condition      4845.0   9065.0     5345.0
# 102894         4.0           Like new      2200.0   2530.0     2530.0
# 70571          1.0                NaN      3750.0   2192.0     1667.0
# 105319         8.0                NaN      2832.0   4300.0     2832.4
# ...            ...                ...         ...      ...        ...
# 135506         NaN     Good condition         NaN   6196.0        NaN
# 135508         NaN                NaN        13.0      NaN        NaN
# 135512         NaN                NaN         NaN    568.0        NaN
# 135515         NaN                NaN         NaN    252.0        NaN
# 135520         NaN                NaN         NaN      NaN        NaN
#
#         NumberOfBathrooms
# 135120              131.0
# 86150                90.0
# 102894               77.0
# 70571                61.0
# 105319               58.0
# ...                   ...
# 135506                NaN
# 135508                NaN
# 135512                NaN
# 135515                NaN
# 135520                NaN
#
# [126328 rows x 25 columns]

# %%
df = df.drop(index=135120)

# %%
num_cols = df.select_dtypes(include=[np.number]).columns

for i in num_cols:
    df.drop(index=df[df[i] < 0].index, inplace=True)
    sns.boxplot(df[i])
    plt.show()

# %%
df['Type'].value_counts()
# Out:
# Type
# Apartment              43849
# House                  34461
# Land                   29510
# Store                   5058
# Farm                    3756
# Building                2392
# Transfer of lease       1580
# Warehouse               1337
# Garage                   885
# Other - Commercial       763
# Office                   696
# Other - Residential      556
# Industrial               397
# Duplex                   363
# Investment               220
# Storage                  166
# Hotel                    148
# Studio                    66
# Estate                    60
# Mansion                   31
# Manor                      6
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Price                         0
# District                      0
# City                          0
# Town                          2
# Type                         15
# EnergyCertificate            13
# Floor                    100304
# Parking                     146
# HasParking                62580
# ConstructionYear          43165
# TotalArea                  7801
# GrossArea                100330
# EnergyEfficiencyLevel     63765
# PublishDate               98420
# Garage                    63765
# Elevator                     30
# ElectricCarsCharging      63765
# TotalRooms                57703
# NumberOfBedrooms          82624
# NumberOfWC                73197
# ConservationStatus       108317
# LivingArea                28473
# LotSize                   89496
# BuiltArea                101526
# NumberOfBathrooms          6494
# dtype: int64

# %%
df = df.dropna(subset='Price')

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [126315 rows x 25 columns]

# %%
df['Price'].hist()
# Out:
# <Axes: >

# %%
# profile = ProfileReport(df, minimal=True)
# profile.to_file('real_estate_report.html')

# %%
print(df.info(memory_usage="deep"))
print(df.memory_usage(deep=True).sum() / 1024**2, "MB")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126315 entries, 0 to 135535
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Price                  126315 non-null  float64
#  1   District               126315 non-null  object
#  2   City                   126315 non-null  object
#  3   Town                   126313 non-null  object
#  4   Type                   126300 non-null  object
#  5   EnergyCertificate      126302 non-null  object
#  6   Floor                  26011 non-null   object
#  7   Parking                126169 non-null  float64
#  8   HasParking             63735 non-null   object
#  9   ConstructionYear       83150 non-null   float64
#  10  TotalArea              118514 non-null  float64
#  11  GrossArea              25985 non-null   float64
#  12  EnergyEfficiencyLevel  62550 non-null   object
#  13  PublishDate            27895 non-null   object
#  14  Garage                 62550 non-null   object
#  15  Elevator               126285 non-null  object
#  16  ElectricCarsCharging   62550 non-null   object
#  17  TotalRooms             68612 non-null   float64
#  18  NumberOfBedrooms       43691 non-null   float64
#  19  NumberOfWC             53118 non-null   float64
#  20  ConservationStatus     17998 non-null   object
#  21  LivingArea             97842 non-null   float64
#  22  LotSize                36819 non-null   float64
#  23  BuiltArea              24789 non-null   float64
#  24  NumberOfBathrooms      119821 non-null  float64
# dtypes: float64(12), object(13)
# memory usage: 90.2 MB
# None
# 90.24732112884521 MB

# %%
df_num = df.select_dtypes(include='number')

# %%
df = df[df['Price'] != df['Price'].max()]
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [126313 rows x 25 columns]

# %%
from geopy.geocoders import Nominatim
from tqdm import tqdm

# %%
geolocator = Nominatim(user_agent="city_to_coords")

def get_coordinates(city_list):
    results = []
    for city in tqdm(city_list, desc="Обработка городов"):
        try:
            location = geolocator.geocode(city)
            if location:
                results.append((city, location.latitude, location.longitude))
            else:
                results.append((city, None, None))
        except Exception as e:
            print(f"Ошибка при обработке {city}: {e}")
            results.append((city, None, None))
    return results


coords = get_coordinates(df['City'].unique())
coords
# Out:
# Обработка городов:  31%|███       | 85/275 [02:01<07:14,  2.29s/it]
# Ошибка при обработке Mora: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Mora&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Обработка городов: 100%|██████████| 275/275 [06:27<00:00,  1.41s/it]
# [('São Brás de Alportel', 37.1529622, -7.8879138),
#  ('Albufeira', 37.088241, -8.2526339),
#  ('Vila do Bispo', 37.0829799, -8.9096115),
#  ('Portimão', 37.1375808, -8.5368426),
#  ('Faro', 37.0162727, -7.9351771),
#  ('Loulé', 37.1395485, -8.0232598),
#  ('Lagos', 6.4550575, 3.3941795),
#  ('Peniche', 39.3568749, -9.3786838),
#  ('Alcoutim', 37.402329300000005, -7.669049938495098),
#  ('Valpaços', 41.6067883, -7.3108525),
#  ('Lagoa (Algarve)', 37.16173885, -8.50351695),
#  ('Castro Marim', 37.2179367, -7.4457102),
#  ('Olhão', 37.0270369, -7.8411287),
#  ('Vila Real de Santo António', 37.1946052, -7.4155628),
#  ('Silves', 37.26398255, -8.348731138182709),
#  ('Tavira', 37.1262493, -7.6499121),
#  ('Aljezur', 37.3151549, -8.8040533),
#  ('Porto', 41.1494512, -8.6107884),
#  ('Monchique', 37.3179725, -8.5558655),
#  ('Sintra', 38.79846, -9.3881),
#  ('Seia', 40.4200998, -7.7028054),
#  ('Paços de Ferreira', 41.290118, -8.378194008811969),
#  ('Almeida', 40.7263333, -6.9067513),
#  ('Gouveia', -18.4545728, -43.7415904),
#  ('Celorico da Beira', 40.6358841, -7.3928446),
#  ('Mêda', 40.93039395, -7.251758355250185),
#  ('Guarda', 40.7046066, -7.195139236071309),
#  ('Trancoso', 40.77847, -7.34908),
#  ('Matosinhos', 41.1806814, -8.6821998),
#  ('Lisboa', 38.7077507, -9.1365919),
#  ('Fornos de Algodres', 40.6579679, -7.488088682276229),
#  ('Ansião', 39.9113771, -8.4359857),
#  ('Pinhel', 40.779428100000004, -7.103198559781845),
#  ('Manteigas', 40.4005617, -7.5408682),
#  ('Figueira de Castelo Rodrigo', 40.89751, -6.96279),
#  ('Tondela', 40.51642, -8.08053),
#  ('Aguiar da Beira', 40.81718, -7.54312),
#  ('Vila Nova de Foz Côa', 41.0818397, -7.1424138),
#  ('Setúbal', 38.5241783, -8.8932341),
#  ('Sabugal', 40.403494949999995, -7.050143238598633),
#  ('Azambuja', 39.0689884, -8.8684921),
#  ('Coimbra', 40.2111931, -8.4294632),
#  ('Amarante', 41.2699316, -8.0804563),
#  ('Marinha Grande', 39.7495952, -8.9298895),
#  ('Sertã', 39.8052145, -8.096441),
#  ('Gondomar', 41.1398199, -8.5326269),
#  ('Praia da Vitória', 38.739237599999996, -27.156264396780458),
#  ('Alvito', 41.6884643, 13.7432643),
#  ('Seixal', 38.6422246, -9.1072662),
#  ('Penacova', 40.2702086, -8.2810743),
#  ('Soure', -0.7275759, -48.5189785),
#  ('Montemor-o-Velho', 40.172664, -8.6845418),
#  ('Miranda do Corvo', 40.0941517, -8.3336555),
#  ('Condeixa-a-Nova', 40.1138729, -8.4986318),
#  ('Mira', 39.7210593, -1.4395226),
#  ('Figueira da Foz', 40.1485808, -8.855655),
#  ('Leiria', 39.7437902, -8.8071119),
#  ('Oliveira do Hospital', 40.37918575, -7.857214780843502),
#  ('Pampilhosa da Serra', 40.0460143, -7.951515),
#  ('Góis', 40.1546195, -8.1099454),
#  ('Cantanhede', 40.3461879, -8.5940128),
#  ('Penela', 40.029442, -8.3902395),
#  ('Tábua', 40.3602946, -8.0284641),
#  ('Lousã', 40.1111532, -8.2461629),
#  ('Tomar', 39.6036596, -8.4150492),
#  ('Arganil', 40.2202451, -7.980700223101081),
#  ('Vila Nova de Poiares', 40.2106048, -8.2562951),
#  ('Ovar', 48.1523759, 19.4098988),
#  ('Felgueiras', 41.3647716, -8.1989321),
#  ('Redondo', 38.6466891, -7.5467636),
#  ('Évora', 38.5707742, -7.9092808),
#  ('Vendas Novas', 38.6773855, -8.4552427),
#  ('Alcobaça', -17.5215875, -39.1965474),
#  ('Reguengos de Monsaraz', 38.4243996, -7.5347109),
#  ('Viana do Alentejo', 38.3347679, -8.0043972),
#  ('Montemor-o-Novo', 38.6481777, -8.2115858),
#  ('Rio Maior', 39.3365387, -8.9364098),
#  ('Mealhada', 40.3792003, -8.4517733),
#  ('Arraiolos', 38.7227289, -7.9853053),
#  ('Portel', -1.9387118, -50.8240402),
#  ('Estremoz', 38.8432944, -7.586907),
#  ('Vila Viçosa', 38.7774063, -7.4166909),
#  ('Cascais', 38.6968919, -9.4204495),
#  ('Borba', 38.8057942, -7.4542105),
#  ('Mora', None, None),
#  ('Alandroal', 38.60240485, -7.384427441025773),
#  ('Benavente', 42.0032862, -5.6738595),
#  ('Mourão', 38.29755475, -7.2223345372362076),
#  ('Esposende', 41.5315251, -8.7792538),
#  ('Mafra', 38.9369782, -9.3282374),
#  ('Vila Franca de Xira', 38.91206415, -8.988923439153135),
#  ('Odivelas', 38.7904338, -9.1792617),
#  ('Loures', 38.8308741, -9.1684512),
#  ('Alenquer', 39.056633, -9.0076057),
#  ('Oeiras', 38.6925777, -9.3123076),
#  ('Amadora', 38.758959, -9.2365233),
#  ('Arruda dos Vinhos', 38.98303, -9.07763),
#  ('Lourinhã', 39.2433932, -9.3119326),
#  ('Torres Vedras', 39.0930856, -9.260741),
#  ('Sobral de Monte Agraço', 39.01835, -9.15171),
#  ('Cadaval', 39.242859, -9.1026628),
#  ('Ponta Delgada', 37.7393398, -25.6689503),
#  ('Mesão Frio', 41.1604717, -7.8883733),
#  ('Elvas', 38.8806123, -7.1637237),
#  ('Braga', 41.5510583, -8.4280045),
#  ('Bombarral', 39.2670652, -9.1584324),
#  ('Óbidos', 39.3619514, -9.157153),
#  ('Caldas da Rainha', 39.4071857, -9.1346004),
#  ('Figueiró dos Vinhos', 39.9024537, -8.2753006),
#  ('Pombal', 39.9161851, -8.6279171),
#  ('Alvaiázere', 39.816133300000004, -8.402050612289344),
#  ('Porto de Mós', 39.6023941, -8.8185271),
#  ('Batalha', 39.6578998, -8.8243713),
#  ('Nazaré', -13.0345586, -39.0062515),
#  ('Pedrógão Grande', 39.9169584, -8.145564),
#  ('Castanheira de Pêra', 40.0047265, -8.2091368),
#  ('Marco de Canaveses', 41.1616546, -8.12779201865893),
#  ('Maia', 41.237345649999995, -8.629998173364326),
#  ('Paredes', 40.0659163, -2.8544122),
#  ('Ourém', 39.65679, -8.57963),
#  ('Fafe', 41.451406, -8.1708502),
#  ('Barcelos', 41.5314496, -8.6192306),
#  ('Miranda do Douro', 41.5000816, -6.271331),
#  ('Guimarães', 41.4417677, -8.2955712),
#  ('Mogadouro', 41.3418708, -6.7121674),
#  ('Póvoa de Lanhoso', 41.5759516, -8.2699521),
#  ('Cabeceiras de Basto', 41.5136392, -7.9878132),
#  ('Celorico de Basto', 41.3879363, -8.0002089),
#  ('Vila Verde', 41.6488247, -8.4362569),
#  ('Terras de Bouro', 41.7190293, -8.3083026),
#  ('Vila Nova de Famalicão', 41.4065175, -8.5187481),
#  ('Vila Flor', 41.3067941, -7.1517712),
#  ('Bragança', 41.5084468, -6.773302360533066),
#  ('Mirandela', 41.489615, -7.1774792),
#  ('Vieira do Minho', 41.6347151, -8.1425725),
#  ('Amares', 41.6309663, -8.3510599),
#  ('Vizela', 41.3767158, -8.3083651),
#  ('Macedo de Cavaleiros', 41.5362124, -6.9560267),
#  ('Torre de Moncorvo', 41.1739499, -7.0526159),
#  ('Carrazeda de Ansiães', 41.2435491, -7.3054015),
#  ('Sines', 37.956549, -8.8689639),
#  ('Freixo de Espada à Cinta', 41.0913764, -6.8078692),
#  ('Beja', 38.0154479, -7.8650368),
#  ('Moura', 38.1409785, -7.4500699),
#  ('Serpa', 37.9436517, -7.5966902),
#  ('Odemira', 37.5976, -8.6422),
#  ('Vinhais', 41.8336062, -7.007716),
#  ('Ourique', 37.651112, -8.2237262),
#  ('Aljustrel', 37.89032505, -8.196352126164136),
#  ('Ferreira do Alentejo', 38.0585086, -8.1138197),
#  ('Mértola', 37.642043, -7.6606447),
#  ('Vidigueira', 38.2101595, -7.8014517),
#  ('Cuba', 23.0131338, -80.8328748),
#  ('Castro Verde', 37.697995, -8.082275),
#  ('Almodôvar', 37.511607, -8.0603168),
#  ('Barrancos', 38.1315902, -6.9779893),
#  ('Santa Maria da Feira', 40.9254179, -8.5426688),
#  ('Estarreja', 40.7523494, -8.5703455),
#  ('Águeda', 40.5785006, -8.4438017),
#  ('Vimioso', 41.5849534, -6.5291002),
#  ('Valença', 44.9332277, 4.8920811),
#  ('Montijo', 38.9098936, -6.6151799),
#  ('Alfândega da Fé', 41.3419743, -6.9611439),
#  ('Espinho', 41.0083643, -8.6394111),
#  ('Aveiro', 40.640496, -8.6537841),
#  ('Anadia', 40.4426833, -8.4359581),
#  ('Oliveira do Bairro', 40.5138208, -8.4928163),
#  ('Albergaria-a-Velha', 40.6906888, -8.4792205),
#  ('Murtosa', 40.7606571, -8.671705662529222),
#  ('Vagos', 40.5538919, -8.680915),
#  ('Oliveira de Azeméis', 40.8390118, -8.4777807),
#  ('Vale de Cambra', 40.8498115, -8.3939142),
#  ('Sever do Vouga', 40.7341808, -8.3702781),
#  ('Ílhavo', 40.6001108, -8.6666667),
#  ('São João da Madeira', 40.897404, -8.490683816868543),
#  ('Castelo de Paiva', 41.0410042, -8.271775),
#  ('Arouca', 40.9289214, -8.2441746),
#  ('Boticas', 41.6881921, -7.6645346),
#  ('Peso da Régua', 41.1637043, -7.7875821),
#  ('Chaves', 41.7399003, -7.4715213),
#  ('Vila Pouca de Aguiar', 41.5007614, -7.6442868),
#  ('Vila Real', 39.9372616, -0.1004465),
#  ('Alijó', 41.2768619, -7.4753795),
#  ('Sabrosa', 41.2663847, -7.5757615),
#  ('Santa Marta de Penaguião', 41.2100446, -7.78473),
#  ('Mondim de Basto', 41.4102874, -7.9533527),
#  ('Murça', 41.42591455, -7.465569503607106),
#  ('Montalegre', 41.8232206, -7.7923142),
#  ('Ribeira de Pena', 41.5217103, -7.795143),
#  ('Vila do Conde', 41.3540398, -8.7435403),
#  ('Fundão', 40.1408065, -7.5017521),
#  ('Vila Nova de Gaia', 41.1300103, -8.6058415),
#  ('Belmonte', 39.5592831, -2.7038117),
#  ('Covilhã', 40.2804021, -7.504191),
#  ('Idanha-a-Nova', 39.9260883, -7.2436356),
#  ('Proença-a-Nova', 39.74995, -7.92494),
#  ('Penamacor', 40.168928, -7.1712605),
#  ('Vila Velha de Ródão', 39.6545418, -7.6723114),
#  ('Vila de Rei', 39.6759822, -8.1442213),
#  ('Castelo Branco', 39.97675825, -7.446059929966704),
#  ('Oleiros', 43.354837200000006, -8.329088217619127),
#  ('Santa Cruz', 28.467178, -16.2507843),
#  ('Trofa', 41.3363471, -8.5585061),
#  ('Lagoa (São Miguel)', -22.2875473, -47.54612269434941),
#  ('Golegã', 39.4017959, -8.4867361),
#  ('Almada', 38.6831302, -9.1576301),
#  ('Vila Franca do Campo', 37.7171624, -25.4335352),
#  ('Valongo', 41.1909794, -8.4980511),
#  ('Penafiel', 41.2061892, -8.2855653),
#  ('Barreiro', 38.6340657, -9.047855912091004),
#  ('Sesimbra', 38.4436932, -9.0996273),
#  ('Cartaxo', 39.1619462, -8.7863222),
#  ('Santarém', 39.2363637, -8.6867081),
#  ('Almeirim', -1.5290377, -52.5788111),
#  ('Abrantes', 39.4629232, -8.1976171),
#  ('Constância', 39.4750609, -8.33819),
#  ('Salvaterra de Magos', 39.0249942, -8.7929278),
#  ('Ferreira do Zêzere', 39.6934308, -8.2905545),
#  ('Castro Daire', 40.9014091, -7.9311761),
#  ('Torres Novas', 39.47962, -8.53955),
#  ('Vila Nova da Barquinha', 39.4840045, -8.429939692509734),
#  ('Coruche', 38.958218, -8.5283498),
#  ('Sardoal', 39.53347, -8.16034),
#  ('Mação', 39.554608, -7.9957035),
#  ('Santo Tirso', 41.3440057, -8.4772021),
#  ('Entroncamento', 39.4652196, -8.4682137),
#  ('Chamusca', 39.3560025, -8.4802892),
#  ('Alcanena', 39.4585519, -8.6697497),
#  ('Alpiarça', 39.2599352, -8.5845144),
#  ('Baião', 41.1616306, -8.0355439),
#  ('Lousada', 41.2773789, -8.2826293),
#  ('Porto Santo', 33.0657845, -16.336223627136313),
#  ('Póvoa de Varzim', 41.3794188, -8.7598689),
#  ('Fronteira', -20.286111, -49.202778),
#  ('Vila do Porto', 36.97262155, -25.10264949987561),
#  ('Penedono', 40.9899414, -7.3941885),
#  ('Alter do Chão', 39.2001177, -7.659037),
#  ('Alcácer do Sal', 38.3729735, -8.5122705),
#  ('Angra do Heroísmo', 38.6593167, -27.2195578),
#  ('Ribeira Grande', 37.8136666, -25.464434187880435),
#  ('Viana do Castelo', 41.694867, -8.831088),
#  ('Velas', 38.6797531, -28.2052961),
#  ('Santiago do Cacém', 38.018461, -8.6937882),
#  ('Marvão', 39.394765, -7.3775491),
#  ('Arcos de Valdevez', 41.8471981, -8.417882),
#  ('Vila Nova de Cerveira', 41.9403912, -8.7436068),
#  ('Caminha', 41.8757598, -8.8388375),
#  ('Ponte de Lima', 41.7675021, -8.5830992),
#  ('Ponte da Barca', 41.8076477, -8.416428),
#  ('Melgaço', 42.1130412, -8.2593422),
#  ('Monção', -3.4842036, -45.2515472),
#  ('Paredes de Coura', 41.913389800000004, -8.56396258972716),
#  ('Palmela', 38.569601, -8.9011653),
#  ('Alcochete', 38.7560499, -8.9608437),
#  ('Grândola', 38.1761212, -8.5680717),
#  ('Moita', 38.6523995, -8.9935314),
#  ('Machico', 32.722875, -16.7659069),
#  ('Funchal', 32.6496497, -16.9086783),
#  ('Porto Moniz', 32.8669649, -17.1666328),
#  ('Avis', 39.0559501, -7.8897441),
#  ('Campo Maior', -4.8339574, -42.1739786),
#  ('Portalegre', 39.2076447, -7.721513354015343),
#  ('Ponte de Sor', 39.2519303, -8.008997),
#  ('Gavião', -11.4714303, -39.7826316),
#  ('Crato', -7.2369112, -39.4149236),
#  ('Monforte', 39.0531482, -7.4389355),
#  ('Sousel', 38.95224, -7.67603),
#  ('Nisa', 43.7009358, 7.2683912),
#  ('Arronches', 39.122106, -7.2853362),
#  ('Castelo de Vide', 39.4152274, -7.4554188),
#  ('Brasil', -10.3333333, -53.2),
#  ('Mortágua', 40.3972486, -8.2287169),
#  ('Cinfães', 41.03267975, -8.108007450852401),
#  ('Horta', 38.5795831, -28.70962954787518),
#  ('Santa Cruz das Flores', 39.47455555, -31.198541227280693)]

# %%
l = []
la = []
c = []
for i in coords: 
    la.append(i[1])
    l.append(i[2])

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  \
# 0                    NaN      114.0        NaN                   NaN
# 1                 1990.0       27.0        NaN                   NaN
# 2                 2003.0       84.0        NaN                   NaN
# 3                 1985.0       68.0        NaN                   NaN
# 4                 1950.0       78.0        NaN                   NaN
# ...                  ...        ...        ...                   ...
# 135531            1982.0      188.0        NaN                     F
# 135532            2010.0       39.0        NaN                    NC
# 135533            1987.0       69.0        NaN                    NC
# 135534               NaN       90.0        NaN                    NC
# 135535               NaN      100.0        NaN                    NC
#
#                 PublishDate Garage Elevator ElectricCarsCharging  TotalRooms  \
# 0                       NaN    NaN     True                  NaN         2.0
# 1                       NaN    NaN     True                  NaN         0.0
# 2                       NaN    NaN    False                  NaN         2.0
# 3                       NaN    NaN     True                  NaN         2.0
# 4                       NaN    NaN    False                  NaN         4.0
# ...                     ...    ...      ...                  ...         ...
# 135531                  NaN   True    False                False         NaN
# 135532                  NaN   True    False                False         NaN
# 135533                  NaN  False    False                False         NaN
# 135534  2022-07-07 16:06:50  False    False                False         NaN
# 135535  2023-01-05 15:37:09  False    False                False         NaN
#
#         NumberOfBedrooms  NumberOfWC ConservationStatus  LivingArea  LotSize  \
# 0                    NaN         NaN                NaN       114.0      NaN
# 1                    NaN         NaN                NaN        27.0      NaN
# 2                    NaN         NaN                NaN        84.0      NaN
# 3                    NaN         NaN                NaN        68.0      NaN
# 4                    NaN         NaN                NaN        78.0      NaN
# ...                  ...         ...                ...         ...      ...
# 135531               3.0         1.0                NaN       190.0  18240.0
# 135532               1.0         NaN                New        39.0      NaN
# 135533               2.0         1.0                NaN        84.0      NaN
# 135534               NaN         0.0                NaN         NaN    300.0
# 135535               NaN         0.0                NaN         NaN    100.0
#
#         BuiltArea  NumberOfBathrooms
# 0             NaN                2.0
# 1             NaN                1.0
# 2             NaN                2.0
# 3             NaN                1.0
# 4             NaN                2.0
# ...           ...                ...
# 135531     238.00                3.0
# 135532      60.00                1.0
# 135533      84.50                2.0
# 135534     240.88                0.0
# 135535        NaN                0.0
#
# [126313 rows x 25 columns]

# %%
df['lactitude'] = df['City'].map(dict(zip(df['City'].unique(), la)))
df['longitude'] = df['City'].map(dict(zip(df['City'].unique(), l)))
# Out:
# /tmp/ipykernel_5739/2819840563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lactitude'] = df['City'].map(dict(zip(df['City'].unique(), la)))
# /tmp/ipykernel_5739/2819840563.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'] = df['City'].map(dict(zip(df['City'].unique(), l)))

# %%
df['PublishDate']
# Out:
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#                  ...
# 135531                    NaN
# 135532                    NaN
# 135533                    NaN
# 135534    2022-07-07 16:06:50
# 135535    2023-01-05 15:37:09
# Name: PublishDate, Length: 126313, dtype: object

# %%
import re

pattern = r"\d{4}-\d{2}-\d{2}"

for i in df.dropna().index:
    re.findall(pattern, df['PublishDate'][i])

# %%
df['ExtractedDate'] = df['PublishDate'].dropna().apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)
# Out:
# /tmp/ipykernel_5739/1427836694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ExtractedDate'] = df['PublishDate'].dropna().apply(lambda x: re.findall(pattern, x)[0] if re.findall(pattern, x) else None)

# %%
df['ExtractedDate'].unique()
# Out:
# array([nan, '2024-10-21', '2024-10-18', '2024-10-17', '2024-10-16',
#        '2024-10-15', '2024-10-14', '2024-10-11', '2024-10-10',
#        '2024-10-12', '2024-10-09', '2024-10-08', '2024-10-07',
#        '2024-10-04', '2024-10-03', '2024-10-02', '2024-10-01',
#        '2024-10-06', '2024-09-30', '2024-09-26', '2024-09-20',
#        '2024-09-19', '2024-09-18', '2024-09-27', '2024-09-16',
#        '2024-09-13', '2024-09-17', '2024-09-12', '2024-09-11',
#        '2024-09-10', '2024-09-09', '2024-09-06', '2024-09-05',
#        '2024-09-04', '2024-09-03', '2024-09-02', '2024-08-31',
#        '2024-08-30', '2024-08-29', '2024-08-28', '2024-08-27',
#        '2024-08-26', '2024-08-23', '2024-08-22', '2024-08-21',
#        '2024-08-16', '2024-08-19', '2024-08-14', '2024-08-13',
#        '2024-08-20', '2024-08-12', '2024-08-09', '2024-08-07',
#        '2024-08-08', '2024-08-06', '2024-08-05', '2024-08-02',
#        '2024-08-01', '2024-07-31', '2024-07-30', '2024-07-29',
#        '2024-07-26', '2024-07-25', '2024-07-24', '2024-07-23',
#        '2024-07-22', '2024-07-19', '2024-07-18', '2024-07-16',
#        '2024-07-15', '2024-07-12', '2024-07-11', '2024-07-10',
#        '2024-07-09', '2024-07-17', '2024-07-05', '2024-07-04',
#        '2024-07-02', '2024-07-01', '2024-06-28', '2024-07-03',
#        '2024-06-27', '2024-06-26', '2024-06-21', '2024-06-19',
#        '2024-06-20', '2024-06-18', '2024-06-14', '2024-06-13',
#        '2024-06-12', '2024-06-22', '2024-06-24', '2024-06-11',
#        '2024-06-10', '2024-06-08', '2024-06-07', '2024-06-06',
#        '2024-06-05', '2024-06-04', '2024-06-17', '2024-06-03',
#        '2024-05-31', '2024-05-29', '2024-05-28', '2024-05-24',
#        '2024-05-23', '2024-05-22', '2024-05-21', '2024-05-27',
#        '2024-05-17', '2024-05-20', '2024-05-16', '2024-05-14',
#        '2024-05-13', '2024-05-09', '2024-05-07', '2024-05-06',
#        '2024-05-03', '2024-05-10', '2024-04-30', '2024-05-08',
#        '2024-04-29', '2024-04-26', '2024-05-15', '2024-04-24',
#        '2024-04-23', '2024-04-22', '2024-05-02', '2024-04-19',
#        '2024-04-18', '2024-04-16', '2024-04-17', '2024-04-15',
#        '2024-04-14', '2024-04-09', '2024-04-05', '2024-04-04',
#        '2024-04-03', '2024-04-10', '2024-04-08', '2024-03-27',
#        '2024-03-28', '2024-03-26', '2024-03-25', '2024-03-22',
#        '2024-03-20', '2024-03-18', '2024-03-14', '2024-03-08',
#        '2024-03-07', '2024-03-06', '2024-03-04', '2024-03-01',
#        '2024-02-29', '2024-02-27', '2024-02-26', '2024-02-23',
#        '2024-02-21', '2024-02-20', '2024-02-19', '2024-02-28',
#        '2024-02-12', '2024-03-05', '2024-02-08', '2024-02-09',
#        '2024-02-06', '2024-02-05', '2024-01-30', '2024-02-15',
#        '2024-01-24', '2024-01-19', '2024-01-18', '2024-01-31',
#        '2024-02-14', '2024-02-07', '2024-01-11', '2024-01-10',
#        '2023-12-29', '2024-01-02', '2023-12-27', '2023-12-19',
#        '2024-01-09', '2023-12-16', '2023-12-12', '2023-11-30',
#        '2023-11-29', '2023-11-27', '2023-11-28', '2023-12-04',
#        '2023-12-05', '2023-12-06', '2023-11-21', '2023-11-16',
#        '2023-11-20', '2023-10-31', '2023-10-30', '2023-11-15',
#        '2023-10-24', '2023-10-13', '2023-10-06', '2023-09-26',
#        '2023-09-29', '2023-09-12', '2023-08-29', '2023-09-27',
#        '2023-08-30', '2023-10-04', '2023-08-04', '2023-08-10',
#        '2023-07-19', '2023-07-07', '2023-06-30', '2023-06-29',
#        '2024-01-03', '2023-05-31', '2023-05-30', '2023-05-16',
#        '2023-05-17', '2023-05-23', '2023-05-03', '2023-03-20',
#        '2023-03-03', '2023-04-11', '2023-02-20', '2023-01-24',
#        '2023-01-06', '2022-11-30', '2022-11-14', '2022-10-28',
#        '2022-09-22', '2022-08-31', '2022-07-26', '2022-07-28',
#        '2022-07-20', '2022-12-27', '2022-06-15', '2022-02-21',
#        '2022-02-18', '2024-01-08', '2023-04-18', '2021-10-11',
#        '2021-09-13', '2021-05-13', '2021-04-29', '2020-11-11',
#        '2024-06-25', '2024-04-11', '2024-03-23', '2024-03-21',
#        '2024-03-19', '2024-02-02', '2022-10-03', '2022-05-20',
#        '2024-10-19', '2024-10-05', '2024-09-14', '2024-08-24',
#        '2024-07-21', '2024-07-08', '2024-07-06', '2024-06-09',
#        '2024-06-15', '2024-05-18', '2024-04-12', '2024-04-13',
#        '2024-04-02', '2024-03-30', '2024-03-29', '2024-03-16',
#        '2024-03-15', '2024-03-13', '2024-03-12', '2024-02-22',
#        '2024-02-16', '2024-03-11', '2024-02-01', '2024-01-29',
#        '2024-01-26', '2024-01-25', '2024-01-23', '2024-01-17',
#        '2024-01-15', '2024-01-22', '2024-01-05', '2024-01-04',
#        '2024-01-12', '2023-12-23', '2023-12-22', '2023-12-20',
#        '2023-12-15', '2023-12-14', '2023-12-13', '2023-12-07',
#        '2024-09-25', '2023-11-23', '2023-12-26', '2023-11-22',
#        '2023-11-03', '2023-11-08', '2023-10-26', '2023-10-25',
#        '2023-10-20', '2023-10-16', '2023-11-17', '2023-10-09',
#        '2023-10-27', '2023-10-03', '2023-09-28', '2023-10-11',
#        '2023-09-25', '2023-09-21', '2023-09-20', '2023-09-15',
#        '2023-09-02', '2023-09-07', '2023-08-31', '2023-08-25',
#        '2023-09-06', '2023-08-22', '2023-08-18', '2023-08-21',
#        '2023-08-14', '2023-08-28', '2023-09-05', '2023-09-18',
#        '2023-08-09', '2023-07-29', '2023-07-25', '2023-08-03',
#        '2023-08-01', '2023-07-21', '2023-08-11', '2023-07-13',
#        '2023-07-12', '2023-07-28', '2023-06-22', '2023-06-21',
#        '2023-06-28', '2023-09-11', '2023-06-13', '2023-06-12',
#        '2023-06-14', '2023-06-07', '2023-06-26', '2023-06-05',
#        '2023-10-19', '2023-05-18', '2023-05-24', '2023-05-12',
#        '2023-05-13', '2023-06-06', '2023-04-17', '2023-04-06',
#        '2023-04-12', '2023-04-04', '2023-03-21', '2023-03-01',
#        '2023-03-07', '2023-02-28', '2023-02-17', '2023-02-16',
#        '2023-02-11', '2023-02-06', '2023-01-09', '2023-05-25',
#        '2023-01-19', '2022-12-22', '2022-12-05', '2022-11-22',
#        '2022-11-11', '2023-03-30', '2022-11-03', '2022-10-04',
#        '2022-10-22', '2022-10-06', '2022-09-29', '2022-09-26',
#        '2022-09-12', '2022-09-06', '2022-09-07', '2022-08-30',
#        '2022-08-08', '2022-08-02', '2022-03-02', '2021-01-24',
#        '2024-09-29', '2024-09-07', '2024-08-15', '2024-08-10',
#        '2024-08-11', '2024-08-03', '2024-07-20', '2024-05-30',
#        '2024-06-29', '2024-04-20', '2024-04-06', '2024-04-01',
#        '2024-05-11', '2024-03-09', '2024-02-24', '2024-01-16',
#        '2024-04-25', '2023-12-21', '2023-12-18', '2023-12-11',
#        '2023-09-30', '2023-10-12', '2023-09-01', '2023-09-19',
#        '2023-07-27', '2023-07-06', '2023-06-23', '2023-06-16',
#        '2023-05-10', '2023-04-14', '2023-04-27', '2023-03-31',
#        '2023-02-01', '2023-05-26', '2024-07-27', '2022-10-10',
#        '2022-09-23', '2022-08-22', '2022-07-22', '2022-07-05',
#        '2022-05-07', '2022-03-24', '2022-02-10', '2022-02-15',
#        '2022-01-04', '2021-08-30', '2021-04-03', '2021-02-06',
#        '2020-10-16', '2020-09-18', '2024-05-25', '2024-02-10',
#        '2023-11-10', '2023-11-06', '2023-10-28', '2023-10-23',
#        '2023-10-10', '2023-09-22', '2023-08-24', '2023-08-16',
#        '2023-07-11', '2023-07-03', '2023-07-05', '2023-05-08',
#        '2023-07-18', '2023-05-05', '2023-04-03', '2023-03-24',
#        '2023-03-22', '2023-02-15', '2023-01-31', '2022-12-20',
#        '2022-12-13', '2022-12-09', '2022-09-30', '2022-10-24',
#        '2022-09-27', '2022-09-28', '2022-08-18', '2022-06-29',
#        '2022-06-09', '2022-05-26', '2022-05-18', '2022-05-05',
#        '2022-04-13', '2022-02-24', '2021-08-16', '2021-07-23',
#        '2021-06-29', '2021-06-04', '2021-04-23', '2020-11-23',
#        '2020-11-10', '2020-09-25', '2020-09-22', '2024-10-20',
#        '2024-05-04', '2024-04-27', '2023-10-18', '2023-09-14',
#        '2023-09-09', '2023-03-14', '2023-02-24', '2021-05-06',
#        '2024-09-21', '2024-09-08', '2024-06-30', '2024-06-01',
#        '2024-05-12', '2023-12-28', '2023-11-07', '2023-11-13',
#        '2023-09-08', '2023-11-09', '2023-08-08', '2023-08-07',
#        '2023-07-04', '2023-05-29', '2023-04-20', '2023-04-21',
#        '2023-06-20', '2023-09-13', '2023-03-29', '2023-03-15',
#        '2023-03-16', '2023-02-13', '2023-01-20', '2022-12-19',
#        '2022-09-21', '2022-09-16', '2022-09-09', '2023-03-23',
#        '2022-06-28', '2022-06-21', '2022-06-08', '2022-06-04',
#        '2022-03-04', '2022-03-09', '2022-02-16', '2023-01-18',
#        '2021-05-19', '2020-11-19', '2021-03-26', '2023-04-19',
#        '2024-09-23', '2024-08-17', '2024-07-07', '2023-06-02',
#        '2023-04-28', '2023-03-17', '2023-02-07', '2021-11-03',
#        '2023-11-24', '2023-06-01', '2023-05-22', '2023-05-11',
#        '2023-05-20', '2023-01-04', '2023-01-03', '2022-12-23',
#        '2022-11-04', '2022-09-01', '2022-08-25', '2022-07-11',
#        '2022-07-29', '2022-05-06', '2022-01-24', '2022-01-07',
#        '2021-06-28', '2021-05-28', '2020-12-11', '2018-10-31',
#        '2024-09-24', '2024-09-15', '2024-08-04', '2024-07-13',
#        '2024-06-02', '2024-05-01', '2024-05-05', '2024-02-11',
#        '2024-02-03', '2024-01-20', '2023-12-30', '2023-11-18',
#        '2023-11-02', '2023-10-17', '2023-10-02', '2023-08-17',
#        '2023-06-27', '2023-04-26', '2023-02-27', '2024-08-18',
#        '2022-12-26', '2022-12-15', '2022-12-12', '2022-12-06',
#        '2022-11-29', '2022-11-24', '2022-10-27', '2022-05-31',
#        '2022-05-16', '2022-05-04', '2022-04-29', '2022-03-31',
#        '2023-01-02', '2020-10-09', '2020-08-08', '2024-08-25',
#        '2024-06-16', '2023-11-14', '2023-08-23', '2023-07-17',
#        '2023-07-14', '2023-07-24', '2023-06-19', '2023-06-15',
#        '2023-05-04', '2023-04-13', '2023-03-10', '2023-03-04',
#        '2023-03-02', '2023-01-13', '2022-11-07', '2022-10-01',
#        '2022-09-02', '2022-06-27', '2022-06-23', '2022-05-24',
#        '2022-04-21', '2022-04-12', '2022-03-11', '2021-11-26',
#        '2021-11-04', '2021-06-11', '2021-01-28', '2020-12-18',
#        '2020-11-04', '2020-10-30', '2020-09-23', '2023-01-05',
#        '2023-05-15', '2021-04-19', '2021-05-05', '2018-04-09',
#        '2024-10-13', '2023-11-25', '2023-10-05', '2023-05-02',
#        '2023-02-02', '2022-07-15', '2023-05-19', '2023-02-08',
#        '2021-11-18', '2021-08-11', '2021-10-20', '2024-05-19',
#        '2022-11-25', '2022-11-12', '2022-08-06', '2024-10-22',
#        '2024-10-23', '2024-10-24', '2023-04-24', '2024-10-25',
#        '2024-10-26', '2024-10-28', '2024-10-29', '2024-10-30',
#        '2024-10-31', '2024-11-01', '2024-11-02', '2024-11-03',
#        '2024-11-04', '2021-02-23', '2024-11-05', '2023-07-31',
#        '2024-11-06', '2024-11-07', '2024-11-08', '2024-11-09',
#        '2024-11-11', '2024-11-12', '2022-01-31', '2024-11-13',
#        '2024-11-14', '2023-12-01', '2024-11-15', '2024-11-16',
#        '2024-11-17', '2024-11-18', '2024-11-19', '2022-05-03',
#        '2024-11-20', '2024-11-21', '2024-11-22', '2024-11-23',
#        '2024-11-24', '2024-11-25', '2024-11-26', '2024-11-27',
#        '2021-08-26', '2020-06-05', '2020-06-03', '2020-05-07',
#        '2020-05-06', '2020-05-05', '2019-06-13', '2018-08-22',
#        '2024-11-28', '2024-11-29', '2024-11-30', '2024-12-01',
#        '2024-12-02', '2024-12-03', '2024-12-04', '2024-12-05',
#        '2024-12-06', '2024-02-17', '2024-12-07', '2024-12-08',
#        '2024-12-09', '2024-12-10', '2024-12-11', '2024-12-12',
#        '2024-12-13', '2024-12-14', '2024-12-15', '2020-09-30',
#        '2024-12-16', '2024-12-17', '2024-12-18', '2024-12-19',
#        '2024-12-20', '2024-12-21', '2024-12-22', '2024-12-23',
#        '2024-12-24', '2024-12-26', '2024-12-27', '2022-07-12',
#        '2016-03-22', '2022-10-13', '2023-01-17', '2018-11-08',
#        '2023-07-26', '2023-07-10', '2021-06-21', '2022-08-11',
#        '2022-08-05', '2022-03-28', '2021-10-18', '2020-08-25',
#        '2016-02-27', '2021-10-01', '2020-07-01', '2018-10-18',
#        '2018-10-01', '2018-09-24', '2018-09-11', '2018-09-04',
#        '2018-08-31', '2018-08-20', '2018-08-18', '2018-08-09',
#        '2018-08-03', '2018-07-11', '2018-07-06', '2018-07-05',
#        '2018-06-20', '2018-06-05', '2018-05-24', '2018-05-23',
#        '2018-05-14', '2018-05-02', '2018-04-30', '2018-04-10',
#        '2017-07-20', '2017-07-14', '2018-02-08', '2016-10-03',
#        '2022-06-22', '2024-12-29', '2015-10-20', '2015-07-15',
#        '2015-07-08', '2014-11-20', '2018-01-23', '2014-06-23',
#        '2012-08-02', '2011-11-17', '2011-07-05', '2011-03-21',
#        '2010-03-16', '2010-03-04', '2024-12-30', '2024-12-28',
#        '2024-12-31', '2025-01-02', '2025-01-03', '2025-01-04',
#        '2024-01-06', '2025-01-05', '2025-01-06', '2025-01-07',
#        '2025-01-08', '2025-01-09', '2025-01-10', '2021-12-27',
#        '2025-01-11', '2025-01-14', '2025-01-13', '2025-01-15',
#        '2025-01-16', '2025-01-17', '2025-01-18', '2025-01-19',
#        '2025-01-20', '2020-10-22', '2023-02-10', '2018-06-12',
#        '2022-06-01', '2020-08-17', '2015-11-26', '2019-08-30',
#        '2021-09-20', '2023-09-04', '2025-01-21', '2025-01-22',
#        '2025-01-23', '2025-01-24', '2025-01-25', '2025-01-26',
#        '2025-01-27', '2025-01-28', '2025-01-29', '2022-11-23',
#        '2022-07-14', '2022-10-11', '2021-04-14', '2021-08-19',
#        '2022-07-07'], dtype=object)

# %%
df['ExtractedDate'] = pd.to_datetime(df['ExtractedDate'])
# Out:
# /tmp/ipykernel_5739/4084587608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ExtractedDate'] = pd.to_datetime(df['ExtractedDate'])

# %%
df = df.drop(columns=['PublishDate'])

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel Garage  \
# 0                    NaN      114.0        NaN                   NaN    NaN
# 1                 1990.0       27.0        NaN                   NaN    NaN
# 2                 2003.0       84.0        NaN                   NaN    NaN
# 3                 1985.0       68.0        NaN                   NaN    NaN
# 4                 1950.0       78.0        NaN                   NaN    NaN
# ...                  ...        ...        ...                   ...    ...
# 135531            1982.0      188.0        NaN                     F   True
# 135532            2010.0       39.0        NaN                    NC   True
# 135533            1987.0       69.0        NaN                    NC  False
# 135534               NaN       90.0        NaN                    NC  False
# 135535               NaN      100.0        NaN                    NC  False
#
#        Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 0          True                  NaN         2.0               NaN
# 1          True                  NaN         0.0               NaN
# 2         False                  NaN         2.0               NaN
# 3          True                  NaN         2.0               NaN
# 4         False                  NaN         4.0               NaN
# ...         ...                  ...         ...               ...
# 135531    False                False         NaN               3.0
# 135532    False                False         NaN               1.0
# 135533    False                False         NaN               2.0
# 135534    False                False         NaN               NaN
# 135535    False                False         NaN               NaN
#
#         NumberOfWC ConservationStatus  LivingArea  LotSize  BuiltArea  \
# 0              NaN                NaN       114.0      NaN        NaN
# 1              NaN                NaN        27.0      NaN        NaN
# 2              NaN                NaN        84.0      NaN        NaN
# 3              NaN                NaN        68.0      NaN        NaN
# 4              NaN                NaN        78.0      NaN        NaN
# ...            ...                ...         ...      ...        ...
# 135531         1.0                NaN       190.0  18240.0     238.00
# 135532         NaN                New        39.0      NaN      60.00
# 135533         1.0                NaN        84.0      NaN      84.50
# 135534         0.0                NaN         NaN    300.0     240.88
# 135535         0.0                NaN         NaN    100.0        NaN
#
#         NumberOfBathrooms  lactitude  longitude ExtractedDate
# 0                     2.0  37.152962  -7.887914           NaT
# 1                     1.0  37.088241  -8.252634           NaT
# 2                     2.0  37.082980  -8.909612           NaT
# 3                     1.0  37.137581  -8.536843           NaT
# 4                     2.0  37.016273  -7.935177           NaT
# ...                   ...        ...        ...           ...
# 135531                3.0  41.606788  -7.310853           NaT
# 135532                1.0  41.823221  -7.792314           NaT
# 135533                2.0  41.276862  -7.475379           NaT
# 135534                0.0  41.266385  -7.575761    2022-07-07
# 135535                0.0  41.606788  -7.310853    2023-01-05
#
# [126313 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Price', 'District', 'City', 'Town', 'Type', 'EnergyCertificate',
#        'Floor', 'Parking', 'HasParking', 'ConstructionYear', 'TotalArea',
#        'GrossArea', 'EnergyEfficiencyLevel', 'Garage', 'Elevator',
#        'ElectricCarsCharging', 'TotalRooms', 'NumberOfBedrooms', 'NumberOfWC',
#        'ConservationStatus', 'LivingArea', 'LotSize', 'BuiltArea',
#        'NumberOfBathrooms', 'lactitude', 'longitude', 'ExtractedDate'],
#       dtype='object')

# %%
df['EnergyCertificate'].unique()
# Out:
# array(['A+', 'NC', 'D', 'C', 'A', 'B-', 'E', 'B', 'F', 'G',
#        'Not available', nan, 'No Certificate'], dtype=object)

# %%
def encode(x):
    if x == 'A+':
        return 7.5
    elif x == 'A':
        return 7
    elif x == 'B':
        return 6
    elif x == 'B-':
        return 5.5
    elif x == 'C':
        return 4
    elif x == 'D':
        return 3
    elif x == 'E':
        return 2
    elif x == 'F':
        return 1
    elif x == 'G':
        return 0
    else:
        return None

# %%
df
# Out:
#            Price   District                  City                       Town  \
# 0       250000.0       Faro  São Brás de Alportel       São Brás de Alportel
# 1         9500.0       Faro             Albufeira  Albufeira e Olhos de Água
# 2       580000.0       Faro         Vila do Bispo                     Budens
# 3       350000.0       Faro              Portimão                   Portimão
# 4       175000.0       Faro                  Faro      Faro (Sé e São Pedro)
# ...          ...        ...                   ...                        ...
# 135531  349900.0  Vila Real              Valpaços         Valpaços e Sanfins
# 135532   77500.0  Vila Real            Montalegre                      Salto
# 135533   50000.0  Vila Real                 Alijó            Castedo e Cotas
# 135534   36000.0  Vila Real               Sabrosa                      Paços
# 135535   35000.0  Vila Real              Valpaços                    Algeriz
#
#              Type EnergyCertificate      Floor  Parking HasParking  \
# 0       Apartment                A+  2nd Floor      1.0       True
# 1       Apartment                NC  1st Floor      0.0      False
# 2       Apartment                 D  3rd Floor      1.0       True
# 3       Apartment                 C  4th Floor      0.0      False
# 4           House                NC        NaN      0.0      False
# ...           ...               ...        ...      ...        ...
# 135531      House                 F        NaN      1.0        NaN
# 135532  Apartment                NC        NaN      0.0        NaN
# 135533      House                NC        NaN      1.0        NaN
# 135534       Land                NC        NaN      0.0        NaN
# 135535       Land                NC        NaN      0.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel Garage  \
# 0                    NaN      114.0        NaN                   NaN    NaN
# 1                 1990.0       27.0        NaN                   NaN    NaN
# 2                 2003.0       84.0        NaN                   NaN    NaN
# 3                 1985.0       68.0        NaN                   NaN    NaN
# 4                 1950.0       78.0        NaN                   NaN    NaN
# ...                  ...        ...        ...                   ...    ...
# 135531            1982.0      188.0        NaN                     F   True
# 135532            2010.0       39.0        NaN                    NC   True
# 135533            1987.0       69.0        NaN                    NC  False
# 135534               NaN       90.0        NaN                    NC  False
# 135535               NaN      100.0        NaN                    NC  False
#
#        Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 0          True                  NaN         2.0               NaN
# 1          True                  NaN         0.0               NaN
# 2         False                  NaN         2.0               NaN
# 3          True                  NaN         2.0               NaN
# 4         False                  NaN         4.0               NaN
# ...         ...                  ...         ...               ...
# 135531    False                False         NaN               3.0
# 135532    False                False         NaN               1.0
# 135533    False                False         NaN               2.0
# 135534    False                False         NaN               NaN
# 135535    False                False         NaN               NaN
#
#         NumberOfWC ConservationStatus  LivingArea  LotSize  BuiltArea  \
# 0              NaN                NaN       114.0      NaN        NaN
# 1              NaN                NaN        27.0      NaN        NaN
# 2              NaN                NaN        84.0      NaN        NaN
# 3              NaN                NaN        68.0      NaN        NaN
# 4              NaN                NaN        78.0      NaN        NaN
# ...            ...                ...         ...      ...        ...
# 135531         1.0                NaN       190.0  18240.0     238.00
# 135532         NaN                New        39.0      NaN      60.00
# 135533         1.0                NaN        84.0      NaN      84.50
# 135534         0.0                NaN         NaN    300.0     240.88
# 135535         0.0                NaN         NaN    100.0        NaN
#
#         NumberOfBathrooms  lactitude  longitude ExtractedDate
# 0                     2.0  37.152962  -7.887914           NaT
# 1                     1.0  37.088241  -8.252634           NaT
# 2                     2.0  37.082980  -8.909612           NaT
# 3                     1.0  37.137581  -8.536843           NaT
# 4                     2.0  37.016273  -7.935177           NaT
# ...                   ...        ...        ...           ...
# 135531                3.0  41.606788  -7.310853           NaT
# 135532                1.0  41.823221  -7.792314           NaT
# 135533                2.0  41.276862  -7.475379           NaT
# 135534                0.0  41.266385  -7.575761    2022-07-07
# 135535                0.0  41.606788  -7.310853    2023-01-05
#
# [126313 rows x 27 columns]

# %%
df[['EnergyCertificate', 'EnergyEfficiencyLevel']] = df[['EnergyCertificate', 'EnergyEfficiencyLevel']].map(lambda x: encode(x))

# %%
si = SimpleImputer(strategy='most_frequent')
df[['EnergyCertificate', 'EnergyEfficiencyLevel']] = SimpleImputer(strategy='most_frequent').fit_transform(df[['EnergyCertificate', 'EnergyEfficiencyLevel']])

# %%
df = df.drop(columns='City')

# %%
df.iloc[50000:100000]['ExtractedDate'].unique()
# Out:
# <DatetimeArray>
# [                'NaT', '2024-10-21 00:00:00', '2024-10-18 00:00:00',
#  '2024-10-17 00:00:00', '2024-10-16 00:00:00', '2024-10-15 00:00:00',
#  '2024-10-14 00:00:00', '2024-10-11 00:00:00', '2024-10-10 00:00:00',
#  '2024-10-12 00:00:00',
#  ...
#  '2022-03-11 00:00:00', '2021-11-26 00:00:00', '2021-11-04 00:00:00',
#  '2021-06-11 00:00:00', '2021-01-28 00:00:00', '2020-12-18 00:00:00',
#  '2020-11-04 00:00:00', '2020-10-30 00:00:00', '2020-09-23 00:00:00',
#  '2023-01-05 00:00:00']
# Length: 625, dtype: datetime64[ns]

# %%
df = df.iloc[50000:100000]

# %%
df['ExtractedDate'].fillna(df['ExtractedDate'].mode()[0], inplace=True)

# %%
df
# Out:
#            Price  District                         Town       Type  \
# 52522   138000.0   Coimbra            Lousã e Vilarinho  Apartment
# 52523    50000.0   Coimbra    Santo António dos Olivais     Garage
# 52524   199000.0   Coimbra            Granja do Ulmeiro  Apartment
# 52526   270000.0   Coimbra    Santo António dos Olivais  Apartment
# 52527   700000.0   Coimbra         Buarcos e São Julião      House
# ...          ...       ...                          ...        ...
# 106248  320000.0  Santarém                    Marinhais      House
# 106249   49900.0  Santarém   Chamusca e Pinheiro Grande      House
# 106250  295000.0  Santarém          Vila Chã de Ourique      House
# 106251   59000.0  Santarém  Nossa Senhora Misericórdias       Land
# 106252  308000.0  Santarém      Cartaxo e Vale da Pinta      House
#
#         EnergyCertificate             Floor  Parking HasParking  \
# 52522                 2.0         3rd Floor      1.0       True
# 52523                 4.0               NaN      1.0       True
# 52524                 6.0      Ground Floor      1.0       True
# 52526                 3.0  Above 10th Floor      0.0      False
# 52527                 3.0               NaN      3.0       True
# ...                   ...               ...      ...        ...
# 106248                3.0               NaN      0.0        NaN
# 106249                4.0               NaN      0.0        NaN
# 106250                2.0               NaN      1.0        NaN
# 106251                4.0               NaN      0.0        NaN
# 106252                4.0               NaN      1.0        NaN
#
#         ConstructionYear  TotalArea  GrossArea  EnergyEfficiencyLevel Garage  \
# 52522             2002.0      140.0      140.0                    4.0    NaN
# 52523                NaN       26.0       26.0                    4.0    NaN
# 52524                NaN      120.0        NaN                    4.0    NaN
# 52526             1988.0      124.0        NaN                    4.0    NaN
# 52527             2000.0      732.0        NaN                    4.0    NaN
# ...                  ...        ...        ...                    ...    ...
# 106248            2001.0      207.0        NaN                    3.0  False
# 106249            1951.0       76.0        NaN                    4.0  False
# 106250            1999.0      150.0        NaN                    2.0   True
# 106251               NaN  3468000.0        NaN                    4.0  False
# 106252            2016.0      183.0        NaN                    4.0  False
#
#        Elevator ElectricCarsCharging  TotalRooms  NumberOfBedrooms  \
# 52522     False                  NaN         3.0               NaN
# 52523     False                  NaN         NaN               NaN
# 52524      True                  NaN         2.0               NaN
# 52526      True                  NaN         3.0               NaN
# 52527     False                  NaN         5.0               NaN
# ...         ...                  ...         ...               ...
# 106248    False                False         NaN               3.0
# 106249    False                False         5.0               4.0
# 106250    False                False         5.0               3.0
# 106251    False                False         NaN               NaN
# 106252    False                False         NaN               3.0
#
#         NumberOfWC ConservationStatus  LivingArea  LotSize  BuiltArea  \
# 52522          NaN                NaN       108.0      NaN        NaN
# 52523          NaN                NaN         NaN      NaN        NaN
# 52524          NaN                NaN       120.0      NaN        NaN
# 52526          NaN                NaN       110.0      NaN        NaN
# 52527          NaN                NaN       458.0      NaN        NaN
# ...            ...                ...         ...      ...        ...
# 106248         0.0                NaN       207.0      NaN        NaN
# 106249         0.0                NaN        76.0   2400.0       76.0
# 106250         1.0                NaN       130.0   1028.0        NaN
# 106251         NaN                NaN    265130.0   3468.0   477230.0
# 106252         0.0                NaN       165.0   5400.0        NaN
#
#         NumberOfBathrooms  lactitude  longitude ExtractedDate
# 52522                 2.0  40.111153  -8.246163    2024-10-17
# 52523                 0.0  40.211193  -8.429463    2024-10-17
# 52524                 2.0  -0.727576 -48.518979    2024-10-17
# 52526                 2.0  40.211193  -8.429463    2024-10-17
# 52527                 6.0  40.148581  -8.855655    2024-10-17
# ...                   ...        ...        ...           ...
# 106248                3.0  39.024994  -8.792928    2024-10-02
# 106249                0.0  39.356003  -8.480289    2024-10-02
# 106250                3.0  39.161946  -8.786322    2024-10-07
# 106251                NaN  39.656790  -8.579630    2024-10-02
# 106252                3.0  39.161946  -8.786322    2024-10-17
#
# [50000 rows x 26 columns]

# %%
df = df.drop(columns=df.isna().all()[df.isna().all() == True].index)

# %%
df['DaysSinceStart'] = (df['ExtractedDate'] - min(df['ExtractedDate'])).dt.days

# %%
df = df.drop(columns='ExtractedDate')

# %%
X = df.drop(columns='Price')
y = df['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
num_cols = X_train.select_dtypes(include=['number', 'datetime']).columns
cat_cols = X_train.select_dtypes(include='object').columns

# %%
df.dtypes
# Out:
# Price                    float64
# District                  object
# Town                      object
# Type                      object
# EnergyCertificate        float64
# Floor                     object
# Parking                  float64
# HasParking                object
# ConstructionYear         float64
# TotalArea                float64
# GrossArea                float64
# EnergyEfficiencyLevel    float64
# Garage                    object
# Elevator                  object
# ElectricCarsCharging      object
# TotalRooms               float64
# NumberOfBedrooms         float64
# NumberOfWC               float64
# ConservationStatus        object
# LivingArea               float64
# LotSize                  float64
# BuiltArea                float64
# NumberOfBathrooms        float64
# lactitude                float64
# longitude                float64
# DaysSinceStart             int64
# dtype: object

# %%
X_test[num_cols]
# Out:
#         EnergyCertificate  Parking  ConstructionYear  TotalArea  GrossArea  \
# 95553                 4.0      1.0            2022.0       66.0        NaN
# 53969                 3.0      2.0            2004.0      155.0        NaN
# 66208                 4.0      3.0               NaN      843.0        NaN
# 93046                 2.0      0.0            1970.0       69.0        NaN
# 60219                 3.0      1.0            1986.0      114.0        NaN
# ...                   ...      ...               ...        ...        ...
# 100401                4.0      0.0               NaN        NaN        NaN
# 97674                 4.0      1.0            2022.0       71.0        NaN
# 78888                 4.0      0.0               NaN        NaN        NaN
# 61989                 4.0      0.0               NaN      650.0      650.0
# 76891                 7.0      1.0            2024.0       87.0        NaN
#
#         EnergyEfficiencyLevel  TotalRooms  NumberOfBedrooms  NumberOfWC  \
# 95553                     4.0         NaN               1.0         0.0
# 53969                     4.0         4.0               NaN         NaN
# 66208                     4.0         NaN               NaN         NaN
# 93046                     2.0         NaN               1.0         0.0
# 60219                     4.0         3.0               NaN         NaN
# ...                       ...         ...               ...         ...
# 100401                    4.0         NaN               NaN         NaN
# 97674                     4.0         2.0               1.0         1.0
# 78888                     4.0         NaN               NaN         0.0
# 61989                     4.0         NaN               NaN         NaN
# 76891                     7.0         NaN               2.0         2.0
#
#         LivingArea  LotSize  BuiltArea  NumberOfBathrooms  lactitude  \
# 95553         66.0      NaN       70.6                0.0  38.707751
# 53969        129.0      NaN        NaN                3.0  40.140806
# 66208          NaN      NaN        NaN                0.0  40.578501
# 93046         60.0      NaN        NaN                1.0  38.707751
# 60219        110.0      NaN        NaN                2.0  41.551058
# ...            ...      ...        ...                ...        ...
# 100401         NaN   2241.0        NaN                NaN  41.206189
# 97674         71.0   3258.0       71.0                1.0  38.707751
# 78888          NaN   2730.0        NaN                0.0  40.346188
# 61989        650.0      NaN        NaN                0.0  41.290118
# 76891         87.0      NaN        NaN                2.0  40.280402
#
#         longitude  DaysSinceStart
# 95553   -9.136592            2178
# 53969   -7.501752            2178
# 66208   -8.443802            2178
# 93046   -9.136592            2010
# 60219   -8.428005            2178
# ...           ...             ...
# 100401  -8.285565            2074
# 97674   -9.136592            2178
# 78888   -8.594013            2178
# 61989   -8.378194            2178
# 76891   -7.504191            2178
#
# [16500 rows x 16 columns]

# %%
# class PriceRelatedOrdinalEncoder(BaseEstimator, TransformerMixin):
#     def __init__(self, cols_to_encode):
#         self.cols_to_encode = cols_to_encode
#         self.order = {}
#         self.encoder = None
        
#     def fit(self, X, y=None):
#         # Преобразуем numpy массив в DataFrame
#         X_df = pd.DataFrame(X, columns=self.cols_to_encode)
#         X_df['Price'] = y  # Добавляем столбец с ценами
        
#         for col in self.cols_to_encode:
#             self.order[col] = list(X_df.groupby(col)['Price'].agg('mean').sort_values(ascending=True).index)
        
#         self.encoder = OrdinalEncoder(categories=list(self.order.values()), 
#                                     handle_unknown='use_encoded_value', 
#                                     unknown_value=-1)
#         self.encoder.fit(X_df[self.cols_to_encode])
#         return self
        
#     def transform(self, X):
#         # Преобразуем входные данные в DataFrame если это numpy массив
#         if isinstance(X, np.ndarray):
#             X = pd.DataFrame(X, columns=self.cols_to_encode)
            
#         return self.encoder.transform(X[self.cols_to_encode])
    

# class SafePowerTransformer(BaseEstimator, TransformerMixin):
#     def __init__(self):
#         self.pt_dict = {}

#     def fit(self, X, y=None):
#         # Проверяем, что X является DataFrame, иначе преобразуем
#         if not isinstance(X, pd.DataFrame):
#             X = pd.DataFrame(X)
        
#         # Создаем трансформаторы для каждого столбца
#         for col in X.columns:
#             self.pt_dict[col] = PowerTransformer()
#             try:
#                 # Применяем fit к каждому столбцу
#                 self.pt_dict[col].fit(X[[col]])  # Передаем в виде DataFrame
#             except:
#                 self.pt_dict[col] = None
                        
#         return self

#     def transform(self, X):
#         # Проверяем, что X является DataFrame, иначе преобразуем
#         if not isinstance(X, pd.DataFrame):
#             X = pd.DataFrame(X)
        
#         # Применяем трансформаторы
#         for col in X.columns:
#             if self.pt_dict.get(col) is not None:
#                 X[col] = self.pt_dict[col].transform(X[[col]])  # Передаем в виде DataFrame

#         return X

# %%
all_models_errors = []

# %%
os.makedirs("mlflow_artifacts", exist_ok=True)

def create_pipeline(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 3, 10)
    num_pipeline = Pipeline([
        ('imputer', KNNImputer(n_neighbors=n_neighbors)),
        ('scaler', PowerTransformer())  # Пример преобразования
    ])
    
    cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', CatBoostEncoder()),
        ('scaler', PowerTransformer())
    ])

    model = trial.suggest_categorical('model', ['lgbm', 'xgb', 'catboost'])

    if model == 'xgb':
        n_estimators = 300
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
        max_depth = trial.suggest_int('max_depth', 1, 10)
        reg_alpha = trial.suggest_float('reg_alpha', 0.1, 4)
        reg_lambda = trial.suggest_float('reg_lambda', 0.01, 1)
        subsample = trial.suggest_float('subsample', 0.5, 1)
        colsample_bytree = trial.suggest_float('colsample_bytree', 0.5, 1)
        regressor = XGBRegressor(n_estimators=n_estimators,
                                learning_rate=learning_rate,
                                max_depth=max_depth,
                                reg_alpha=reg_alpha,
                                reg_lambda=reg_lambda,
                                subsample=subsample,
                                colsample_bytree=colsample_bytree,
                                verbosity=0, 
                                random_state=42)
        
    elif model == 'catboost':
        n_estimators = 300
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
        max_depth = trial.suggest_int('max_depth', 1, 10)
        reg_lambda = trial.suggest_float('reg_lambda', 0.01, 1)
        regressor = CatBoostRegressor(n_estimators=n_estimators, 
                                      learning_rate=learning_rate, 
                                      max_depth=max_depth,
                                      reg_lambda=reg_lambda, 
                                      verbose=0, 
                                      random_seed=42)
        
    else:
        n_estimators = 300
        learning_rate = trial.suggest_float('learning_rate', 0.001, 0.3)
        max_depth = trial.suggest_int('max_depth', 1, 10)
        reg_alpha = trial.suggest_float('reg_alpha', 0.1, 4)
        reg_lambda = trial.suggest_float('reg_lambda', 0.01, 1)
        regressor = LGBMRegressor(n_estimators=n_estimators, 
                                  learning_rate=learning_rate, 
                                  max_depth=max_depth,
                                  reg_alpha=reg_alpha,
                                  reg_lambda=reg_lambda, 
                                  verbosity=0, 
                                  random_state=42)
    
    pipeline = Pipeline([
        ('transform', ColumnTransformer([
            ('num', num_pipeline, num_cols),
            ('cat', cat_pipeline, cat_cols)])),
        ('model', regressor)
    ])
    
    return pipeline


def objective(trial):
    pipeline_opt = create_pipeline(trial)
    
    pipeline_opt.fit(X_train, y_train)
    predictions = pipeline_opt.predict(X_test)
    
    metric = mean_absolute_error(y_test, predictions)  # Метрика
    
    return metric


# После того как Optuna завершит поиск:
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

# Логируем лучший пайплайн и его параметры
best_trial = study.best_trial
final_pipeline = create_pipeline(best_trial)

# Логируем лучший пайплайн в MLflow
with mlflow.start_run():
    mlflow.log_params(best_trial.params)
    
    # Логируем метрики и артефакты для лучшего пайплайна
    final_pipeline.fit(X_train, y_train)
    predictions = final_pipeline.predict(X_test)
    
    final_metric = mean_squared_error(y_test, predictions)
    
    # Логируем метрики
    mlflow.log_metric("Final MSE", final_metric)
    
    mae = mean_absolute_error(y_test, predictions)
    abs_errors = np.abs(y_test - predictions)
    rel_errors = abs_errors / y_test
    med_rel = np.median(rel_errors)
    mean_rel = np.mean(rel_errors)
    rel_distance = np.abs(med_rel - mean_rel)
    med_abs = np.median(abs_errors)
    mean_abs = np.mean(abs_errors)
    abs_distance = np.abs(med_abs - mean_abs)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    r_squared = r2_score(y_test, predictions)
    adj_r_squared = 1 - (1 - r_squared) * (y_test.shape[0] - 1) / (y_test.shape[0] - X_test.shape[1] - 1)   
    mape = mean_absolute_percentage_error(y_test, predictions)
    evs = explained_variance_score(y_test, predictions)    
    # Логируем метрики
    
    mlflow.log_metrics({
    "MAE": mae,
    "MSE": final_metric,
    "RMSE": rmse,
    "R2": r_squared,
    "Adjusted R2": adj_r_squared,
    "MAPE": mape,
    "Explained Variance": evs
    })
    mlflow.log_metric("Best Objective Value", study.best_value)
    
    
    # Логируем модель
    example_input = X_test[:5]
    signature = infer_signature(X_test, final_pipeline.predict(X_test))
    mlflow.sklearn.log_model(final_pipeline, "model_pipeline", signature=signature, input_example=example_input)
    
    # Гистограмма абсолютных ошибок
    
    for name, data, xlabel in zip(["error_distribution", "relative_error_distribution"],
                                  [abs_errors, rel_errors],
                                  ["Absolute Errors", "Relative Errors"]):
        plt.figure()
        sns.histplot(data, bins=50)
        plt.xlabel(xlabel)
        plt.title(xlabel)
        save_path = f"mlflow_artifacts/{name}.png"
        plt.savefig(save_path)
        mlflow.log_artifact(save_path)
        plt.close()
    
    # Boxplot графики
    for name, data in zip(["abs_error_boxplot", "rel_error_boxplot"], [abs_errors, rel_errors]):
        plt.figure()
        sns.boxplot(y=data)
        plt.title(name.replace("_", " ").title())
        save_path = f"mlflow_artifacts/{name}.png"
        plt.savefig(save_path)
        mlflow.log_artifact(save_path)
        plt.close()
        
        
    # plt.figure()
    # sns.histplot(abs_errors, bins=50)
    # plt.title('Absolute Errors')
    # plt.axvline(med_abs, color='red', label='Median')
    # plt.axvline(mean_abs, color='green', label='Mean')
    # plt.legend([f'Median: {med_abs:.2f}', f'Mean: {mean_abs:.2f}', f'Δ = {abs_distance:.2f}'])
    # plt.savefig("error_distribution.png")  # Сохраняем график
    # mlflow.log_artifact("error_distribution.png")  # Логируем в MLflow
    
    # plt.close()
    
    # # Гистограмма относительных ошибок
    # plt.figure()
    # sns.histplot(rel_errors, bins=50)
    # plt.title('Relative Errors')
    # plt.axvline(med_rel, color='red', label='Median')
    # plt.axvline(mean_rel, color='green', label='Mean')
    # plt.legend([f'Median: {med_rel:.2f}', f'Mean: {mean_rel:.2f}', f'Δ = {rel_distance:.2f}'])
    # plt.savefig("relative_error_distribution.png")  # Сохраняем график
    # mlflow.log_artifact("relative_error_distribution.png")  # Логируем в MLflow
    
    # plt.close()
    
    # # Boxplot абсолютных ошибок
    # plt.figure()
    # sns.boxplot(abs_errors)
    # plt.title('Absolute Errors Boxplot')
    # plt.savefig("abs_error_boxplot.png")  # Сохраняем график
    # mlflow.log_artifact("abs_error_boxplot.png")  # Логируем в MLflow
    # plt.close()
    
    # # Boxplot относительных ошибок
    # plt.figure()
    # sns.boxplot(rel_errors)
    # plt.title('Relative Errors Boxplot')
    # plt.savefig("rel_error_boxplot.png")  # Сохраняем график
    # mlflow.log_artifact("rel_error_boxplot.png")  # Логируем в MLflow
    # plt.close()
    
best_trial = study.best_trial
final_pipeline = create_pipeline(best_trial)
final_pipeline.fit(X_train, y_train)

# with mlflow.start_run():
#     mlflow.log_params(best_trial.params)
#     mlflow.sklearn.log_model(final_pipeline, "final_model_pipeline")

print("Лучшие параметры:", study.best_params)
print("Лучшая точность:", study.best_value)
# Out:
# [I 2025-03-11 21:19:12,044] A new study created in memory with name: no-name-6c7af6ab-6b3c-45fd-8bd0-11303a62e2fd
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2025-03-11 21:21:40,842] Trial 0 finished with value: 165258.96886521304 and parameters: {'n_neighbors': 4, 'model': 'lgbm', 'learning_rate': 0.15832477909378465, 'max_depth': 7, 'reg_alpha': 3.679595449302735, 'reg_lambda': 0.8399143373475718}. Best is trial 0 with value: 165258.96886521304.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:24:08,676] Trial 1 finished with value: 151280.29221447685 and parameters: {'n_neighbors': 3, 'model': 'xgb', 'learning_rate': 0.02835000258918916, 'max_depth': 9, 'reg_alpha': 1.739446615547373, 'reg_lambda': 0.7928550961555821, 'subsample': 0.9243760914391332, 'colsample_bytree': 0.620863186787163}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:26:36,724] Trial 2 finished with value: 171377.4047105944 and parameters: {'n_neighbors': 8, 'model': 'xgb', 'learning_rate': 0.13029726412094084, 'max_depth': 3, 'reg_alpha': 3.6617509500519687, 'reg_lambda': 0.8572054305683673, 'subsample': 0.7056645046521048, 'colsample_bytree': 0.7419917488593287}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:29:06,578] Trial 3 finished with value: 155060.0468277955 and parameters: {'n_neighbors': 5, 'model': 'catboost', 'learning_rate': 0.11968665114194751, 'max_depth': 8, 'reg_lambda': 0.045480827603566185}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2025-03-11 21:31:35,031] Trial 4 finished with value: 174036.74793727658 and parameters: {'n_neighbors': 8, 'model': 'lgbm', 'learning_rate': 0.2426435027229282, 'max_depth': 7, 'reg_alpha': 1.8627606986006815, 'reg_lambda': 0.5099208072287089}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:34:05,221] Trial 5 finished with value: 156385.88975747777 and parameters: {'n_neighbors': 10, 'model': 'xgb', 'learning_rate': 0.05036432513305791, 'max_depth': 10, 'reg_alpha': 0.7638227309031234, 'reg_lambda': 0.4697244528191351, 'subsample': 0.5139106102070571, 'colsample_bytree': 0.571910295209985}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:36:34,442] Trial 6 finished with value: 160154.67093486106 and parameters: {'n_neighbors': 10, 'model': 'catboost', 'learning_rate': 0.262846982521689, 'max_depth': 7, 'reg_lambda': 0.9701826795239189}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2025-03-11 21:39:02,939] Trial 7 finished with value: 163809.87468605547 and parameters: {'n_neighbors': 6, 'model': 'lgbm', 'learning_rate': 0.11879260506588149, 'max_depth': 7, 'reg_alpha': 1.1108675803266532, 'reg_lambda': 0.0552868503747946}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:41:31,597] Trial 8 finished with value: 157162.57371588552 and parameters: {'n_neighbors': 9, 'model': 'xgb', 'learning_rate': 0.09586791724135468, 'max_depth': 6, 'reg_alpha': 0.12132240309341291, 'reg_lambda': 0.7795302993384109, 'subsample': 0.7344556777968325, 'colsample_bytree': 0.9428728422935443}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:44:01,367] Trial 9 finished with value: 160356.58210630383 and parameters: {'n_neighbors': 5, 'model': 'xgb', 'learning_rate': 0.1228015820357755, 'max_depth': 9, 'reg_alpha': 3.2417597863341387, 'reg_lambda': 0.805825502637652, 'subsample': 0.6415893350558567, 'colsample_bytree': 0.7042594538743903}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:46:28,339] Trial 10 finished with value: 225272.3807708712 and parameters: {'n_neighbors': 3, 'model': 'xgb', 'learning_rate': 0.004263464551390962, 'max_depth': 3, 'reg_alpha': 2.380751539534885, 'reg_lambda': 0.5377350843999011, 'subsample': 0.9909724590695739, 'colsample_bytree': 0.5051519604189375}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:48:59,864] Trial 11 finished with value: 160547.47263839812 and parameters: {'n_neighbors': 3, 'model': 'catboost', 'learning_rate': 0.19879072252547525, 'max_depth': 9, 'reg_lambda': 0.0758463538014339}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:51:28,322] Trial 12 finished with value: 204724.4994849453 and parameters: {'n_neighbors': 5, 'model': 'catboost', 'learning_rate': 0.048896143639644854, 'max_depth': 1, 'reg_lambda': 0.2680888905068559}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:54:01,177] Trial 13 finished with value: 185954.7962263681 and parameters: {'n_neighbors': 4, 'model': 'catboost', 'learning_rate': 0.006718172515197629, 'max_depth': 9, 'reg_lambda': 0.6305121396949657}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:56:38,315] Trial 14 finished with value: 156850.44638506774 and parameters: {'n_neighbors': 6, 'model': 'catboost', 'learning_rate': 0.18735975051844167, 'max_depth': 10, 'reg_lambda': 0.2758369240706038}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 21:59:06,520] Trial 15 finished with value: 158468.8093245611 and parameters: {'n_neighbors': 4, 'model': 'xgb', 'learning_rate': 0.07958368425775894, 'max_depth': 5, 'reg_alpha': 2.311651990886365, 'reg_lambda': 0.30301902869845626, 'subsample': 0.9638133575087071, 'colsample_bytree': 0.8931294662504428}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:01:36,589] Trial 16 finished with value: 158255.71395728475 and parameters: {'n_neighbors': 5, 'model': 'catboost', 'learning_rate': 0.04984500079164521, 'max_depth': 8, 'reg_lambda': 0.6683474961518446}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:04:05,119] Trial 17 finished with value: 177489.34433145996 and parameters: {'n_neighbors': 7, 'model': 'xgb', 'learning_rate': 0.2924213073065254, 'max_depth': 5, 'reg_alpha': 1.648229287630862, 'reg_lambda': 0.9666614074623342, 'subsample': 0.8433238373468508, 'colsample_bytree': 0.6383474890045792}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:06:33,785] Trial 18 finished with value: 157594.07139927076 and parameters: {'n_neighbors': 3, 'model': 'catboost', 'learning_rate': 0.16421274846402006, 'max_depth': 8, 'reg_lambda': 0.3920220129276934}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:09:04,768] Trial 19 finished with value: 155941.1166823083 and parameters: {'n_neighbors': 4, 'model': 'xgb', 'learning_rate': 0.08488915175194121, 'max_depth': 10, 'reg_alpha': 2.8992619023492328, 'reg_lambda': 0.16833514989368348, 'subsample': 0.8615403720308568, 'colsample_bytree': 0.834500255995451}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2025-03-11 22:11:33,333] Trial 20 finished with value: 159171.03073295657 and parameters: {'n_neighbors': 7, 'model': 'lgbm', 'learning_rate': 0.03083956756552643, 'max_depth': 8, 'reg_alpha': 1.2565940046677317, 'reg_lambda': 0.6727552195499511}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:14:04,614] Trial 21 finished with value: 157225.03578705556 and parameters: {'n_neighbors': 4, 'model': 'xgb', 'learning_rate': 0.08514423410120345, 'max_depth': 10, 'reg_alpha': 2.99519318691747, 'reg_lambda': 0.12847341730999237, 'subsample': 0.8615139562878544, 'colsample_bytree': 0.8336835514657068}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:16:34,540] Trial 22 finished with value: 154057.41063191477 and parameters: {'n_neighbors': 5, 'model': 'xgb', 'learning_rate': 0.07869965921644276, 'max_depth': 9, 'reg_alpha': 2.8292764201818734, 'reg_lambda': 0.16677742754662228, 'subsample': 0.866601645333248, 'colsample_bytree': 0.8133000200219136}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:19:04,224] Trial 23 finished with value: 154898.8336415993 and parameters: {'n_neighbors': 6, 'model': 'xgb', 'learning_rate': 0.05986242656182216, 'max_depth': 9, 'reg_alpha': 2.5715788176981396, 'reg_lambda': 0.18757602931967432, 'subsample': 0.9096657091322174, 'colsample_bytree': 0.6548436688894735}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:21:33,936] Trial 24 finished with value: 152072.88338546222 and parameters: {'n_neighbors': 6, 'model': 'xgb', 'learning_rate': 0.027571899019823945, 'max_depth': 9, 'reg_alpha': 2.528928219398142, 'reg_lambda': 0.19688059408582786, 'subsample': 0.9054928962686837, 'colsample_bytree': 0.6605162675528367}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:24:02,401] Trial 25 finished with value: 158622.4126461848 and parameters: {'n_neighbors': 7, 'model': 'xgb', 'learning_rate': 0.03366017226019864, 'max_depth': 6, 'reg_alpha': 1.9634775253631878, 'reg_lambda': 0.38263375123039733, 'subsample': 0.9173914476832665, 'colsample_bytree': 0.6190329881003629}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:26:32,130] Trial 26 finished with value: 155763.5940643608 and parameters: {'n_neighbors': 6, 'model': 'xgb', 'learning_rate': 0.013623184706108446, 'max_depth': 9, 'reg_alpha': 2.7039725655637548, 'reg_lambda': 0.22006914255272536, 'subsample': 0.7846180046832013, 'colsample_bytree': 0.7877268022639917}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:29:00,503] Trial 27 finished with value: 165570.29004245487 and parameters: {'n_neighbors': 8, 'model': 'xgb', 'learning_rate': 0.0253743368085469, 'max_depth': 4, 'reg_alpha': 3.3223422988692137, 'reg_lambda': 0.3657512094933801, 'subsample': 0.9241153803371676, 'colsample_bytree': 0.7015085088772889}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [I 2025-03-11 22:31:29,372] Trial 28 finished with value: 155591.0979439895 and parameters: {'n_neighbors': 5, 'model': 'xgb', 'learning_rate': 0.0624218602512996, 'max_depth': 8, 'reg_alpha': 1.556811358034181, 'reg_lambda': 0.11902292461318298, 'subsample': 0.8170597324328566, 'colsample_bytree': 0.5580734254566525}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [I 2025-03-11 22:33:55,957] Trial 29 finished with value: 158410.3867516933 and parameters: {'n_neighbors': 3, 'model': 'lgbm', 'learning_rate': 0.10465963766496987, 'max_depth': 6, 'reg_alpha': 2.2395067494521075, 'reg_lambda': 0.4499689820623706}. Best is trial 1 with value: 151280.29221447685.
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:239: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/vivaldi/miniconda3/envs/api/lib/python3.10/site-packages/numpy/core/_methods.py:250: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# Лучшие параметры: {'n_neighbors': 3, 'model': 'xgb', 'learning_rate': 0.02835000258918916, 'max_depth': 9, 'reg_alpha': 1.739446615547373, 'reg_lambda': 0.7928550961555821, 'subsample': 0.9243760914391332, 'colsample_bytree': 0.620863186787163}
# Лучшая точность: 151280.29221447685

# %%
from mlflow.models.signature import infer_signature

# Создаем папку для артефактов (если не существует)
os.makedirs("mlflow_artifacts", exist_ok=True)

def create_pipeline(trial):
    n_neighbors = trial.suggest_int('n_neighbors', 3, 10)
    num_pipeline = Pipeline([
        ('imputer', KNNImputer(n_neighbors=n_neighbors)),
        ('scaler', PowerTransformer())
    ])
    
    cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('scaler', PowerTransformer())
    ])

    model = trial.suggest_categorical('model', ['lgbm', 'xgb', 'catboost'])
    
    common_params = {
        'n_estimators': 300,
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3),
        'max_depth': trial.suggest_int('max_depth', 1, 10)
    }
    
    if model == 'xgb':
        regressor = XGBRegressor(**common_params,
                                 reg_alpha=trial.suggest_float('reg_alpha', 0.1, 4),
                                 reg_lambda=trial.suggest_float('reg_lambda', 0.01, 1),
                                 subsample=trial.suggest_float('subsample', 0.5, 1),
                                 colsample_bytree=trial.suggest_float('colsample_bytree', 0.5, 1),
                                 verbosity=0)
    elif model == 'catboost':
        regressor = CatBoostRegressor(**common_params,
                                      reg_lambda=trial.suggest_float('reg_lambda', 0.01, 1),
                                      verbose=0)
    else:
        regressor = LGBMRegressor(**common_params,
                                  reg_alpha=trial.suggest_float('reg_alpha', 0.1, 4),
                                  reg_lambda=trial.suggest_float('reg_lambda', 0.01, 1),
                                  verbosity=-1)
    
    pipeline = Pipeline([
        ('transform', ColumnTransformer([
            ('num', num_pipeline, num_cols),
            ('cat', cat_pipeline, cat_cols)])),
        ('model', regressor)
    ])
    
    return pipeline

def objective(trial):
    pipeline_opt = create_pipeline(trial)
    pipeline_opt.fit(X_train, y_train)
    predictions = pipeline_opt.predict(X_test)
    return mean_absolute_error(y_test, predictions)

# Оптимизация с Optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Обучаем лучший пайплайн
best_trial = study.best_trial
final_pipeline = create_pipeline(best_trial)
final_pipeline.fit(X_train, y_train)
predictions = final_pipeline.predict(X_test)

# Метрики
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, predictions)
adj_r2 = 1 - (1 - r2) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)
mape = mean_absolute_percentage_error(y_test, predictions)
ev_score = explained_variance_score(y_test, predictions)
abs_errors = np.abs(y_test - predictions)
rel_errors = abs_errors / y_test

# Логирование в MLflow
with mlflow.start_run():
    mlflow.log_params(best_trial.params)
    mlflow.log_metrics({
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2,
        "Adjusted R2": adj_r2,
        "MAPE": mape,
        "Explained Variance": ev_score
    })
    
    # Логирование модели
    mlflow.sklearn.log_model(final_pipeline, "final_model_pipeline", input_example=X_test[:5], signature=infer_signature(X_test, predictions))
    
    # Логирование графиков
    for name, data, xlabel in zip(["error_distribution", "relative_error_distribution"],
                                  [abs_errors, rel_errors],
                                  ["Absolute Errors", "Relative Errors"]):
        plt.figure()
        sns.histplot(data, bins=50)
        plt.xlabel(xlabel)
        plt.title(xlabel)
        save_path = f"mlflow_artifacts/{name}.png"
        plt.savefig(save_path)
        mlflow.log_artifact(save_path)
        plt.close()
    
    # Boxplot графики
    for name, data in zip(["abs_error_boxplot", "rel_error_boxplot"], [abs_errors, rel_errors]):
        plt.figure()
        sns.boxplot(y=data)
        plt.title(name.replace("_", " ").title())
        save_path = f"mlflow_artifacts/{name}.png"
        plt.savefig(save_path)
        mlflow.log_artifact(save_path)
        plt.close()
    
print("Лучшие параметры:", study.best_params)
print("Лучшая точность:", study.best_value)

# %%
best_trial = study.best_trial
final_pipeline = create_pipeline(best_trial)
final_pipeline.fit(X_train, y_train)

with mlflow.start_run():
    mlflow.log_params(best_trial.params)
    mlflow.sklearn.log_model(final_pipeline, "final_model_pipeline")

# %%
study.best_params, study.best_value
# Out:
# ({'model': 'xgb',
#   'learning_rate': 0.06747048754087821,
#   'max_depth': 10,
#   'reg_alpha': 2.7428029417005613,
#   'reg_lambda': 0.9457813633431938},
#  75235.06263193868)

# %%
X_train
# Out:
#      District       Type EnergyCertificate         Floor  Parking HasParking  \
# 926      Faro      Store                 D           NaN      0.0      False
# 2968     Faro      House                 A           NaN      0.0      False
# 490      Faro  Apartment                 E     5th Floor      1.0       True
# 2516     Faro  Apartment                 A        Duplex      2.0       True
# 2432     Faro  Apartment                 A     1st Floor      1.0       True
# ...       ...        ...               ...           ...      ...        ...
# 1507     Faro  Apartment                NC  Ground Floor      0.0       True
# 280      Faro  Apartment                A+     6th Floor      1.0       True
# 1205     Faro  Apartment                NC     8th Floor      1.0       True
# 1923   Guarda      House                 F           NaN      0.0      False
# 1406     Faro  Apartment                B-     1st Floor      1.0       True
#
#       ConstructionYear  TotalArea  GrossArea EnergyEfficiencyLevel  ...  \
# 926             2003.0      768.0      164.0                   NaN  ...
# 2968            2022.0       91.0       91.0                   NaN  ...
# 490             1999.0       86.0       86.0                   NaN  ...
# 2516            2023.0      175.0        NaN                   NaN  ...
# 2432            2022.0      236.0      101.0                   NaN  ...
# ...                ...        ...        ...                   ...  ...
# 1507            1990.0       30.0       30.0                   NaN  ...
# 280             2023.0      750.0      106.0                   NaN  ...
# 1205            2000.0       78.0       78.0                   NaN  ...
# 1923            1951.0      191.0      310.0                   NaN  ...
# 1406            1985.0       27.0        NaN                   NaN  ...
#
#      TotalRooms NumberOfBedrooms NumberOfWC ConservationStatus  LivingArea  \
# 926         NaN              NaN        NaN                NaN       118.0
# 2968        1.0              NaN        NaN                NaN        91.0
# 490         1.0              NaN        NaN                NaN        60.0
# 2516        3.0              NaN        NaN                NaN       136.0
# 2432        2.0              NaN        NaN                NaN       101.0
# ...         ...              ...        ...                ...         ...
# 1507        0.0              NaN        NaN                NaN        30.0
# 280         2.0              NaN        NaN                NaN        79.0
# 1205        1.0              NaN        NaN                NaN        78.0
# 1923        3.0              NaN        NaN                NaN       140.0
# 1406        0.0              NaN        NaN                NaN        27.0
#
#       LotSize  BuiltArea NumberOfBathrooms  lactitude  longitude
# 926       NaN        NaN               NaN  37.139548  -8.023260
# 2968      NaN        NaN               2.0  37.161739  -8.503517
# 490       NaN        NaN               1.0  37.139548  -8.023260
# 2516      NaN        NaN               4.0  37.139548  -8.023260
# 2432      NaN        NaN               2.0  37.161739  -8.503517
# ...       ...        ...               ...        ...        ...
# 1507      NaN        NaN               1.0  37.088241  -8.252634
# 280       NaN        NaN               2.0  37.137581  -8.536843
# 1205      NaN        NaN               1.0  37.139548  -8.023260
# 1923      NaN        NaN               0.0  40.930394  -7.251758
# 1406      NaN        NaN               1.0  37.088241  -8.252634
#
# [1800 rows x 24 columns]

# %%
X_test
# Out:
#        District                                               Town  \
# 7607     Lisboa                                       Águas Livres
# 46614     Porto                                          Ermesinde
# 8383     Lisboa                                  Cascais e Estoril
# 7445     Lisboa                               São Domingos de Rana
# 3750    Coimbra  Coimbra (Sé Nova, Santa Cruz, Almedina e São B...
# ...         ...                                                ...
# 41892     Porto  Cedofeita, Santo Ildefonso, Sé, Miragaia, São ...
# 24601  Santarém                                           Alpiarça
# 10057    Guarda                             Rio Torto e Lagarinhos
# 29314   Setúbal                     Charneca de Caparica e Sobreda
# 12218     Braga                       Gondifelos, Cavalões e Outiz
#
#                      Type  EnergyCertificate      Floor  Parking HasParking  \
# 7607   Other - Commercial                4.0   Basement      0.0      False
# 46614               House                2.0        NaN      0.0       True
# 8383            Apartment                3.0  3rd Floor      2.0       True
# 7445                House                7.5        NaN      2.0       True
# 3750                House                3.0        NaN      2.0       True
# ...                   ...                ...        ...      ...        ...
# 41892            Building                2.0        NaN      0.0      False
# 24601                Land                4.0        NaN      0.0      False
# 10057              Estate                4.0        NaN      0.0      False
# 29314                Land                4.0        NaN      0.0      False
# 12218                Land                4.0        NaN      0.0      False
#
#        ConstructionYear  TotalArea  GrossArea  ...  NumberOfBedrooms  \
# 7607             1989.0       80.0       78.0  ...               NaN
# 46614            1988.0      159.0      164.0  ...               NaN
# 8383             1993.0      199.0      259.0  ...               NaN
# 7445                NaN      300.0        NaN  ...               NaN
# 3750             1937.0      159.0      440.0  ...               NaN
# ...                 ...        ...        ...  ...               ...
# 41892            1951.0      450.0        NaN  ...               NaN
# 24601               NaN      432.0      216.0  ...               NaN
# 10057               NaN      159.0        NaN  ...               NaN
# 29314            1979.0      159.0        NaN  ...               NaN
# 12218               NaN      159.0        NaN  ...               NaN
#
#       NumberOfWC ConservationStatus LivingArea  LotSize  BuiltArea  \
# 7607         NaN                NaN        NaN      NaN        NaN
# 46614        NaN                NaN      118.0      NaN        NaN
# 8383         NaN                NaN      180.0      NaN        NaN
# 7445         NaN                NaN      170.0      NaN        NaN
# 3750         NaN                NaN      220.0      NaN        NaN
# ...          ...                ...        ...      ...        ...
# 41892        NaN                NaN      118.0      NaN        NaN
# 24601        NaN                NaN        NaN      NaN        NaN
# 10057        NaN                NaN        NaN      NaN        NaN
# 29314        NaN                NaN      118.0      NaN        NaN
# 12218        NaN                NaN        NaN      NaN        NaN
#
#        NumberOfBathrooms  lactitude  longitude  Days_since_start
# 7607                 2.0  38.758959  -9.236523              5424
# 46614                1.0  41.190979  -8.498051              5424
# 8383                 0.0  38.696892  -9.420450              5424
# 7445                 3.0  38.696892  -9.420450              5424
# 3750                 2.0  40.211193  -8.429463              5424
# ...                  ...        ...        ...               ...
# 41892                5.0  41.149451  -8.610788              5424
# 24601                NaN  39.259935  -8.584514              5424
# 10057                0.0 -18.454573 -43.741590              5424
# 29314                3.0  38.683130  -9.157630              5424
# 12218                0.0  41.406517  -8.518748              5424
#
# [20000 rows x 25 columns]

# %%
for i in list(X_test.columns):
    if i not in list(X_train.columns):
        print(i)
